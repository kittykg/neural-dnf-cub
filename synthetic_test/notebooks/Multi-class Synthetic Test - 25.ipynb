# %%
import re
import sys

sys.path.append('..')
sys.path.append('../..')

# %%
import clingo
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import jaccard_score

import torch
from torch.utils.data import DataLoader

# %%
from dnf_layer import SemiSymbolicLayerType
from rule_learner import DNFClassifierEO, DNFClassifier
from test_common import SyntheticDataset
from utils import DeltaDelayedExponentialDecayScheduler
from dnf_post_train import (
    remove_unused_conjunctions,
    remove_disjunctions_when_empty_conjunctions,
)

# %%
RNG_SEED = 73

NUM_IN = 150
NUM_CONJ = 75
NUM_CLASSES = 25

SYNTH_DATA_PATH = f'synth_multiclass_data_in{NUM_IN}_conj{NUM_CONJ}_out{NUM_CLASSES}.npz'

BATCH_SIZE = 256
NUM_EPOCHS = 100

# %%
torch.manual_seed(RNG_SEED)
np.random.seed(RNG_SEED)

# %%
dnpz = np.load(SYNTH_DATA_PATH)
full_nullary = dnpz['nullary']
full_target = dnpz['target']

# %%
nullary_full_train, nullary_test, target_full_train, target_test = train_test_split(
    full_nullary, full_target, random_state=RNG_SEED)
nullary_train, nullary_val, target_train, target_val = train_test_split(
    nullary_full_train, target_full_train, test_size=0.2, random_state=RNG_SEED
)

train_loader = DataLoader(SyntheticDataset(nullary_train, target_train), BATCH_SIZE)
val_loader = DataLoader(SyntheticDataset(nullary_val, target_val), BATCH_SIZE)
test_loader = DataLoader(SyntheticDataset(nullary_test, target_test), BATCH_SIZE)

# %%
model = DNFClassifierEO(NUM_IN, NUM_CONJ, NUM_CLASSES, 0.1)
delta_decay_scheduler = DeltaDelayedExponentialDecayScheduler(
    initial_delta=0.1,
    delta_decay_delay=10,
    delta_decay_steps=1,
    delta_decay_rate=1.1,
)
optimiser = torch.optim.Adam(model.parameters(), 0.001)
criterion = torch.nn.CrossEntropyLoss()

# %%
for i in range(NUM_EPOCHS):
    model.train()
    epoch_loss = []
    for x, y in train_loader:
        optimiser.zero_grad()
        y_hat = model(x.float())
        loss = criterion(y_hat, y.float())
        loss.backward()
        optimiser.step()

        epoch_loss.append(loss.item())
    
    model.eval()    
    val_correct = 0
    val_total = 0
    for x, y in val_loader:
        with torch.no_grad():
            y_hat = torch.tanh(model(x.float()))
            _, y_pred = torch.max(y_hat, 1)
            val_correct += torch.sum(y_pred == (torch.argmax(y, dim=1))).item()
            val_total += len(y)

    new_delta_val = delta_decay_scheduler.step(model, i)
    avg_loss = sum(epoch_loss) / len(epoch_loss)
    print(f'[{i + 1:3d}] Delta: {new_delta_val:.3f}  '
          f'Train avg loss: {avg_loss:.3f}  '
          f'Val acc: {val_correct / val_total:.3f}')
# Out:
# [  1] Delta: 0.100  Train avg loss: 2.862  Val acc: 0.042
# [  2] Delta: 0.100  Train avg loss: 1.521  Val acc: 0.261
# [  3] Delta: 0.100  Train avg loss: 0.435  Val acc: 0.042
# [  4] Delta: 0.100  Train avg loss: 0.123  Val acc: 0.042
# [  5] Delta: 0.100  Train avg loss: 0.062  Val acc: 0.042
# [  6] Delta: 0.100  Train avg loss: 0.041  Val acc: 0.042
# [  7] Delta: 0.100  Train avg loss: 0.031  Val acc: 0.042
# [  8] Delta: 0.100  Train avg loss: 0.025  Val acc: 0.042
# [  9] Delta: 0.100  Train avg loss: 0.020  Val acc: 0.042
# [ 10] Delta: 0.100  Train avg loss: 0.017  Val acc: 0.042
# [ 11] Delta: 0.100  Train avg loss: 0.015  Val acc: 0.042
# [ 12] Delta: 0.110  Train avg loss: 0.013  Val acc: 0.042
# [ 13] Delta: 0.121  Train avg loss: 0.013  Val acc: 0.042
# [ 14] Delta: 0.133  Train avg loss: 0.013  Val acc: 0.042
# [ 15] Delta: 0.146  Train avg loss: 0.013  Val acc: 0.042
# [ 16] Delta: 0.161  Train avg loss: 0.014  Val acc: 0.042
# [ 17] Delta: 0.177  Train avg loss: 0.015  Val acc: 0.042
# [ 18] Delta: 0.195  Train avg loss: 0.016  Val acc: 0.042
# [ 19] Delta: 0.214  Train avg loss: 0.017  Val acc: 0.042
# [ 20] Delta: 0.236  Train avg loss: 0.019  Val acc: 0.042
# [ 21] Delta: 0.259  Train avg loss: 0.020  Val acc: 0.042
# [ 22] Delta: 0.285  Train avg loss: 0.022  Val acc: 0.042
# [ 23] Delta: 0.314  Train avg loss: 0.024  Val acc: 0.042
# [ 24] Delta: 0.345  Train avg loss: 0.026  Val acc: 0.042
# [ 25] Delta: 0.380  Train avg loss: 0.029  Val acc: 0.044
# [ 26] Delta: 0.418  Train avg loss: 0.032  Val acc: 0.050
# [ 27] Delta: 0.459  Train avg loss: 0.035  Val acc: 0.093
# [ 28] Delta: 0.505  Train avg loss: 0.040  Val acc: 0.228
# [ 29] Delta: 0.556  Train avg loss: 0.045  Val acc: 0.507
# [ 30] Delta: 0.612  Train avg loss: 0.051  Val acc: 0.809
# [ 31] Delta: 0.673  Train avg loss: 0.059  Val acc: 0.713
# [ 32] Delta: 0.740  Train avg loss: 0.068  Val acc: 0.290
# [ 33] Delta: 0.814  Train avg loss: 0.080  Val acc: 0.042
# [ 34] Delta: 0.895  Train avg loss: 0.096  Val acc: 0.042
# [ 35] Delta: 0.985  Train avg loss: 0.127  Val acc: 0.042
# [ 36] Delta: 1.000  Train avg loss: 0.224  Val acc: 0.042
# [ 37] Delta: 1.000  Train avg loss: 0.085  Val acc: 0.042
# [ 38] Delta: 1.000  Train avg loss: 0.051  Val acc: 0.042
# [ 39] Delta: 1.000  Train avg loss: 0.041  Val acc: 0.042
# [ 40] Delta: 1.000  Train avg loss: 0.035  Val acc: 0.042
# [ 41] Delta: 1.000  Train avg loss: 0.031  Val acc: 0.042
# [ 42] Delta: 1.000  Train avg loss: 0.028  Val acc: 0.042
# [ 43] Delta: 1.000  Train avg loss: 0.025  Val acc: 0.042
# [ 44] Delta: 1.000  Train avg loss: 0.023  Val acc: 0.042
# [ 45] Delta: 1.000  Train avg loss: 0.022  Val acc: 0.042
# [ 46] Delta: 1.000  Train avg loss: 0.020  Val acc: 0.042
# [ 47] Delta: 1.000  Train avg loss: 0.019  Val acc: 0.042
# [ 48] Delta: 1.000  Train avg loss: 0.018  Val acc: 0.042
# [ 49] Delta: 1.000  Train avg loss: 0.017  Val acc: 0.042
# [ 50] Delta: 1.000  Train avg loss: 0.016  Val acc: 0.042
# [ 51] Delta: 1.000  Train avg loss: 0.015  Val acc: 0.042
# [ 52] Delta: 1.000  Train avg loss: 0.015  Val acc: 0.042
# [ 53] Delta: 1.000  Train avg loss: 0.014  Val acc: 0.042
# [ 54] Delta: 1.000  Train avg loss: 0.013  Val acc: 0.042
# [ 55] Delta: 1.000  Train avg loss: 0.013  Val acc: 0.042
# [ 56] Delta: 1.000  Train avg loss: 0.012  Val acc: 0.042
# [ 57] Delta: 1.000  Train avg loss: 0.012  Val acc: 0.042
# [ 58] Delta: 1.000  Train avg loss: 0.012  Val acc: 0.042
# [ 59] Delta: 1.000  Train avg loss: 0.011  Val acc: 0.042
# [ 60] Delta: 1.000  Train avg loss: 0.011  Val acc: 0.042
# [ 61] Delta: 1.000  Train avg loss: 0.010  Val acc: 0.042
# [ 62] Delta: 1.000  Train avg loss: 0.010  Val acc: 0.042
# [ 63] Delta: 1.000  Train avg loss: 0.010  Val acc: 0.042
# [ 64] Delta: 1.000  Train avg loss: 0.009  Val acc: 0.042
# [ 65] Delta: 1.000  Train avg loss: 0.009  Val acc: 0.042
# [ 66] Delta: 1.000  Train avg loss: 0.009  Val acc: 0.042
# [ 67] Delta: 1.000  Train avg loss: 0.009  Val acc: 0.042
# [ 68] Delta: 1.000  Train avg loss: 0.008  Val acc: 0.042
# [ 69] Delta: 1.000  Train avg loss: 0.008  Val acc: 0.042
# [ 70] Delta: 1.000  Train avg loss: 0.008  Val acc: 0.042
# [ 71] Delta: 1.000  Train avg loss: 0.008  Val acc: 0.042
# [ 72] Delta: 1.000  Train avg loss: 0.008  Val acc: 0.042
# [ 73] Delta: 1.000  Train avg loss: 0.007  Val acc: 0.042
# [ 74] Delta: 1.000  Train avg loss: 0.007  Val acc: 0.042
# [ 75] Delta: 1.000  Train avg loss: 0.007  Val acc: 0.042
# [ 76] Delta: 1.000  Train avg loss: 0.007  Val acc: 0.042
# [ 77] Delta: 1.000  Train avg loss: 0.007  Val acc: 0.042
# [ 78] Delta: 1.000  Train avg loss: 0.007  Val acc: 0.042
# [ 79] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 80] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 81] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 82] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 83] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 84] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 85] Delta: 1.000  Train avg loss: 0.006  Val acc: 0.042
# [ 86] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 87] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 88] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 89] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 90] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 91] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 92] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 93] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 94] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 95] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 96] Delta: 1.000  Train avg loss: 0.005  Val acc: 0.042
# [ 97] Delta: 1.000  Train avg loss: 0.004  Val acc: 0.042
# [ 98] Delta: 1.000  Train avg loss: 0.004  Val acc: 0.042
# [ 99] Delta: 1.000  Train avg loss: 0.004  Val acc: 0.042
# [100] Delta: 1.000  Train avg loss: 0.004  Val acc: 0.042

# %%
# torch.save(model.state_dict(), f'dnfeo_multi_class_synth_{RNG_SEED}.pth')
# model.load_state_dict(torch.load(f'dnfeo_synth_{RNG_SEED}.pth'))

# %%
model2 = DNFClassifier(NUM_IN, NUM_CONJ, NUM_CLASSES, 1)

sd = model.state_dict()
sd.pop('eo_layer.weights')
model2.load_state_dict(sd)
# Out:
# <All keys matched successfully>

# %%
def eval_multi_class_dnf(model, data_loader):
    # Return accuracy and Jaccard score
    correct = 0
    total = 0
    jaccard_scores = []
    for x, y in data_loader:
        with torch.no_grad():
            y_hat = torch.tanh(model(x.float()))
            _, y_pred = torch.max(y_hat, 1)
            correct += torch.sum(y_pred == (torch.argmax(y, dim=1))).item()
            total += len(y)
            y_hat_jacc = (y_hat > 0).int()
            jacc = jaccard_score(y.detach().cpu().numpy(), y_hat_jacc.detach().cpu().numpy(), average='samples')
            jaccard_scores.append(jacc)

    return (correct / total), (sum(jaccard_scores) / len(jaccard_scores))

# %%
acc, jacc =  eval_multi_class_dnf(model2, test_loader)
print(f'Accuarcy: {acc:.3f}')
print(f'Jaccard:  {jacc:.3f}')
# Out:
# Accuarcy: 1.000
# Jaccard:  0.995

# %% [markdown]
# # Post Training Process

# %%
def prune_layer_weight(
    model,
    layer_type: SemiSymbolicLayerType,
    epsilon: float,
    data_loader: DataLoader,
) -> int:
    if layer_type == SemiSymbolicLayerType.CONJUNCTION:
        curr_weight = model.dnf.conjunctions.weights.data.clone()
    else:
        curr_weight = model.dnf.disjunctions.weights.data.clone()

    _, og_jacc = eval_multi_class_dnf(model, data_loader)

    prune_count = 0
    weight_device = curr_weight.device

    flatten_weight_len = len(torch.reshape(curr_weight, (-1,)))
    base_iterator = range(flatten_weight_len)
    for i in base_iterator:
        curr_weight_flatten = torch.reshape(curr_weight, (-1,))

        if curr_weight_flatten[i] == 0:
            continue

        mask = torch.ones(flatten_weight_len, device=weight_device)
        mask[i] = 0
        mask = mask.reshape(curr_weight.shape)

        masked_weight = curr_weight * mask

        if layer_type == SemiSymbolicLayerType.CONJUNCTION:
            model.dnf.conjunctions.weights.data = masked_weight
        else:
            model.dnf.disjunctions.weights.data = masked_weight

        _, new_jacc = eval_multi_class_dnf(model, data_loader)
        performance_drop = og_jacc - new_jacc
        if performance_drop < epsilon:
            prune_count += 1
            curr_weight *= mask

    if layer_type == SemiSymbolicLayerType.CONJUNCTION:
        model.dnf.conjunctions.weights.data = curr_weight
    else:
        model.dnf.disjunctions.weights.data = curr_weight
    return prune_count

# %%
prune_epsilon = 0.005
print('Prune disj layer')
prune_count = prune_layer_weight(model2, SemiSymbolicLayerType.DISJUNCTION, 
    prune_epsilon, val_loader)
_, new_jacc = eval_multi_class_dnf(model2, val_loader)
print(f'Pruned disj count:   {prune_count}')
print(f'New perf after disj: {new_jacc:.3f}\n')

unused_conj = remove_unused_conjunctions(model)
print(f'Remove unused conjunctions: {unused_conj}')
print()

print('Prune conj layer')
prune_count = prune_layer_weight(model2, SemiSymbolicLayerType.CONJUNCTION, 
    prune_epsilon, val_loader)
_, new_jacc = eval_multi_class_dnf(model2, val_loader)
print(f'Pruned conj count:   {prune_count}')
print(f'New perf after conj: {new_jacc:.3f}\n')

removed_disj = remove_disjunctions_when_empty_conjunctions(model)
print(
    f'Remove disjunction that uses empty conjunctions: {removed_disj}'
)
print()

print('Prune disj layer again')
prune_count = prune_layer_weight(model2, SemiSymbolicLayerType.DISJUNCTION,
    prune_epsilon, val_loader)
_, new_jacc = eval_multi_class_dnf(model2, val_loader)
print(f'Pruned disj count:   {prune_count}')
print(f'New perf after disj: {new_jacc:.3f}')
# Out:
# Prune disj layer
# Pruned disj count:   1844
# New perf after disj: 0.993
#
# Remove unused conjunctions: 0
#
# Prune conj layer
# Pruned conj count:   10203
# New perf after conj: 0.988
#
# Remove disjunction that uses empty conjunctions: 0
#
# Prune disj layer again
# Pruned disj count:   4
# New perf after disj: 0.991

# %%
sd = model.state_dict()
sd.pop('eo_layer.weights')
model2.load_state_dict(sd)
pre_threshold_sd = model2.state_dict()

# %%
def apply_threshold(
    model, og_conj_weight, og_disj_weight, t_val, const: float = 6.0,
) -> None:
    new_conj_weight = (
        (torch.abs(og_conj_weight) > t_val) * torch.sign(og_conj_weight) * const
    )
    model.dnf.conjunctions.weights.data = new_conj_weight

    new_disj_weight = (
        (torch.abs(og_disj_weight) > t_val) * torch.sign(og_disj_weight) * const
    )
    model.dnf.disjunctions.weights.data = new_disj_weight

# %%
# model2.load_state_dict(pre_threshold_sd)

conj_min = torch.min(model2.dnf.conjunctions.weights.data)
conj_max = torch.max(model2.dnf.conjunctions.weights.data)
disj_min = torch.min(model2.dnf.disjunctions.weights.data)
disj_max = torch.max(model2.dnf.disjunctions.weights.data)

abs_max = torch.max(torch.abs(torch.Tensor([conj_min, conj_max, disj_min, disj_max])))

og_conj_weight = model2.dnf.conjunctions.weights.data.clone()
og_disj_weight = model2.dnf.disjunctions.weights.data.clone()

jacc_scores = []
t_vals = torch.arange(0, abs_max + 0.01, 0.01)

for v in t_vals:
    apply_threshold(model2, og_conj_weight, og_disj_weight,
                              v, 6.0)
    _, jacc = eval_multi_class_dnf(model2, val_loader)
    jacc_scores.append(jacc)

best_jacc_score = max(jacc_scores)
best_t = t_vals[torch.argmax(torch.Tensor(jacc_scores))]
print(f'Best t: {best_t.item():.3f}    Acc: {best_jacc_score:.3f}')
apply_threshold(model2, og_conj_weight, og_disj_weight, best_t)
_, final_jacc = eval_multi_class_dnf(model2, val_loader)
print(f'Jacc after threshold: {final_jacc:.3f}')
# Out:
# Best t: 0.150    Acc: 0.227
# Jacc after threshold: 0.227

# %%
final_sd = model2.state_dict()

output_rules = []

# Get all conjunctions
conj_w = final_sd["dnf.conjunctions.weights"]
conjunction_map = dict()
for i, w in enumerate(conj_w):
    if torch.all(w == 0):
        # No conjunction is applied here
        continue

    conjuncts = []
    for j, v in enumerate(w):
        if v < 0:
            # Negative weight, negate the atom
            conjuncts.append(f"not has_attr_{j}")
        elif v > 0:
            # Positive weight, normal atom
            conjuncts.append(f"has_attr_{j}")

    conjunction_map[i] = conjuncts

# Get DNF
disj_w = final_sd["dnf.disjunctions.weights"]
not_covered_classes = []
for i, w in enumerate(disj_w):
    if torch.all(w == 0):
        # No DNF for class i
        not_covered_classes.append(i)
        continue

    disjuncts = []
    for j, v in enumerate(w):
        if v < 0 and j in conjunction_map:
            # Negative weight, negate the existing conjunction
            
            # Need to add auxilary predicate (conj_X) which is not yet
            # in the final rules list
            output_rules.append(
                f"conj_{j} :- {', '.join(conjunction_map[j])}."
            )
            output_rules.append(f"class({i}) :- not conj_{j}.")
        elif v > 0 and j in conjunction_map:
            # Postivie weight, add normal conjunction
            body = ", ".join(conjunction_map[j])
            output_rules.append(f"class({i}) :- {body}.")

# %%
show_statements = [f'#show class/1.']


jacc_scores = []
total_sample_count = 0

for x_batch, y_batch in test_loader:
    for i in range(len(x_batch)):
        x = x_batch[i]
        y = torch.where(y_batch[i] == 1)[0].item()
        x_asp = [f"has_attr_{j}." for j in range(len(x)) if x[j] == 1]
        ctl = clingo.Control(["--warn=none"])
        ctl.add("base", [], " ".join(x_asp + output_rules + show_statements))
        ctl.ground([("base", [])])
        with ctl.solve(yield_=True) as handle:  # type: ignore
            all_answer_sets = [str(a) for a in handle]

        target_class = f"class({y})"

        if len(all_answer_sets) != 1:
            # No or multiple answer sets, should not happen
            print('No or multiple answer sets when evaluating rules.')
            continue

        output_classes = all_answer_sets[0].split(" ")
        output_classes_set = set(output_classes)

        target_class_set = {target_class}

        jacc = len(output_classes_set & target_class_set) / len(
            output_classes_set | target_class_set
        )
        jacc_scores.append(jacc)
        total_sample_count += 1

print(f'Jaccard score: {sum(jacc_scores) / total_sample_count:.3f}')
# Out:
# Jaccard score: 0.226

# %%
output_rules
# Out:
# ['class(0) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(0) :- has_attr_12, has_attr_23, not has_attr_35, not has_attr_39, not has_attr_53, has_attr_66, has_attr_71, has_attr_77, not has_attr_82, has_attr_93, not has_attr_101, not has_attr_103, has_attr_116, not has_attr_120, has_attr_123, not has_attr_124.',
#  'class(0) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(0) :- has_attr_3, has_attr_6, has_attr_14, has_attr_26, has_attr_46, has_attr_52, has_attr_56, has_attr_63, has_attr_68, not has_attr_73, has_attr_74, not has_attr_76, has_attr_90, has_attr_115, has_attr_125, has_attr_130.',
#  'class(0) :- has_attr_5, has_attr_6, has_attr_21, has_attr_23, not has_attr_35, has_attr_66, has_attr_68, has_attr_74, has_attr_77, has_attr_91, has_attr_92, has_attr_101, has_attr_122, has_attr_142, has_attr_147.',
#  'class(0) :- has_attr_2, has_attr_5, has_attr_9, has_attr_11, has_attr_13, has_attr_18, has_attr_19, has_attr_27, has_attr_34, has_attr_36, has_attr_45, has_attr_47, has_attr_56, has_attr_64, has_attr_71, has_attr_74, has_attr_86, has_attr_88, has_attr_94, has_attr_98, has_attr_108, has_attr_117, has_attr_125, has_attr_126, has_attr_129, has_attr_133, has_attr_135, has_attr_138, has_attr_139, has_attr_141, has_attr_148.',
#  'class(0) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(0) :- has_attr_5, has_attr_12, has_attr_14, has_attr_16, has_attr_19, has_attr_24, has_attr_27, has_attr_34, has_attr_39, has_attr_77, has_attr_78, has_attr_79, has_attr_88, has_attr_92, has_attr_94, has_attr_103, has_attr_104, has_attr_108, has_attr_110, has_attr_118, has_attr_126, has_attr_127, has_attr_130, has_attr_133, has_attr_135, has_attr_139, has_attr_140, has_attr_145.',
#  'class(0) :- has_attr_6, has_attr_20, not has_attr_59, has_attr_69, has_attr_82, has_attr_86, not has_attr_89, not has_attr_90, not has_attr_101, not has_attr_103, not has_attr_113, has_attr_116, has_attr_122, not has_attr_129, has_attr_144.',
#  'class(0) :- has_attr_0, has_attr_6, has_attr_9, has_attr_33, has_attr_34, has_attr_43, has_attr_44, has_attr_52, has_attr_53, has_attr_54, has_attr_72, has_attr_75, has_attr_85, has_attr_86, has_attr_92, not has_attr_109, has_attr_124, has_attr_140, has_attr_146, has_attr_148.',
#  'class(0) :- not has_attr_10, not has_attr_11, not has_attr_16, not has_attr_27, not has_attr_34, not has_attr_37, not has_attr_43, has_attr_49, not has_attr_64, not has_attr_71, not has_attr_74, not has_attr_81, not has_attr_87, not has_attr_100, not has_attr_105, not has_attr_118, not has_attr_120, not has_attr_122, not has_attr_127, not has_attr_131, has_attr_134, not has_attr_141, not has_attr_145, has_attr_149.',
#  'class(0) :- not has_attr_4, not has_attr_5, has_attr_9, not has_attr_11, has_attr_16, not has_attr_20, has_attr_23, not has_attr_35, has_attr_49, not has_attr_56, not has_attr_57, not has_attr_62, has_attr_64, has_attr_87, not has_attr_88, not has_attr_93, not has_attr_102, not has_attr_107, not has_attr_119, not has_attr_125, not has_attr_140, has_attr_143.',
#  'class(0) :- has_attr_0, has_attr_4, has_attr_8, has_attr_13, has_attr_18, has_attr_20, has_attr_30, has_attr_31, has_attr_43, has_attr_51, has_attr_52, has_attr_54, has_attr_55, has_attr_57, has_attr_66, has_attr_83, has_attr_94, has_attr_98, has_attr_104, has_attr_106, has_attr_118, has_attr_119, has_attr_125, has_attr_143, has_attr_149.',
#  'class(0) :- not has_attr_1, not has_attr_3, has_attr_4, not has_attr_20, has_attr_25, not has_attr_30, not has_attr_42, not has_attr_46, not has_attr_49, has_attr_67, not has_attr_86, not has_attr_91, not has_attr_93, not has_attr_101, has_attr_108, has_attr_110, not has_attr_114, has_attr_122, not has_attr_123, not has_attr_135, not has_attr_139, not has_attr_142.',
#  'class(0) :- has_attr_8, has_attr_15, has_attr_17, has_attr_18, has_attr_32, has_attr_39, has_attr_42, has_attr_52, has_attr_53, has_attr_57, has_attr_59, has_attr_62, has_attr_63, has_attr_74, has_attr_76, has_attr_82, has_attr_96, has_attr_97, has_attr_100, has_attr_109, has_attr_121, has_attr_122, has_attr_126, has_attr_129, has_attr_140, has_attr_145, has_attr_149.',
#  'class(0) :- has_attr_2, has_attr_6, has_attr_9, has_attr_11, has_attr_27, has_attr_29, has_attr_31, has_attr_43, has_attr_47, has_attr_58, has_attr_86, has_attr_88, has_attr_93, has_attr_122, has_attr_127, has_attr_138, has_attr_141, has_attr_145.',
#  'class(0) :- has_attr_3, has_attr_9, has_attr_13, has_attr_16, has_attr_18, has_attr_26, has_attr_39, has_attr_45, has_attr_52, has_attr_56, has_attr_61, has_attr_63, has_attr_71, has_attr_86, has_attr_92, has_attr_98, has_attr_104, has_attr_107, has_attr_110, has_attr_111, has_attr_115, has_attr_118, has_attr_126, has_attr_129, has_attr_135, has_attr_139, has_attr_143, has_attr_145, has_attr_146, has_attr_148.',
#  'class(1) :- has_attr_2, has_attr_3, has_attr_12, has_attr_17, has_attr_18, has_attr_29, has_attr_39, has_attr_65, has_attr_76, has_attr_85, has_attr_88, has_attr_91, has_attr_111, has_attr_112, has_attr_116, has_attr_120, has_attr_122, has_attr_124.',
#  'class(1) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(1) :- has_attr_4, has_attr_7, has_attr_16, has_attr_19, has_attr_26, has_attr_39, not has_attr_43, has_attr_46, has_attr_54, has_attr_62, has_attr_66, has_attr_79, has_attr_84, has_attr_93, has_attr_97, has_attr_98, has_attr_102, has_attr_114, has_attr_116, has_attr_120, has_attr_130, has_attr_136, has_attr_147.',
#  'class(1) :- not has_attr_6, has_attr_8, has_attr_12, not has_attr_13, not has_attr_14, has_attr_17, has_attr_28, has_attr_35, has_attr_67, has_attr_70, has_attr_75, has_attr_79, has_attr_85, has_attr_103, has_attr_112, has_attr_120, has_attr_129, has_attr_138, has_attr_139, not has_attr_143, has_attr_147.',
#  'class(1) :- has_attr_2, has_attr_3, not has_attr_13, not has_attr_36, has_attr_38, has_attr_43, has_attr_46, not has_attr_56, has_attr_62, has_attr_75, has_attr_95, has_attr_97, has_attr_113, has_attr_114, not has_attr_123, has_attr_125, has_attr_131, has_attr_139, has_attr_140, has_attr_142, not has_attr_147, has_attr_149.',
#  'class(1) :- has_attr_3, not has_attr_5, has_attr_22, has_attr_32, has_attr_45, has_attr_50, has_attr_62, has_attr_64, has_attr_72, has_attr_86, not has_attr_87, not has_attr_92, has_attr_94, has_attr_103, has_attr_119, not has_attr_127, not has_attr_131, has_attr_133, has_attr_134, has_attr_141, has_attr_148.',
#  'class(1) :- has_attr_1, has_attr_7, has_attr_24, not has_attr_55, not has_attr_59, has_attr_61, has_attr_85, has_attr_90, has_attr_92, not has_attr_94, has_attr_99, not has_attr_103, has_attr_104, has_attr_106, has_attr_109, has_attr_112.',
#  'class(1) :- not has_attr_0, has_attr_4, has_attr_14, has_attr_17, not has_attr_37, has_attr_46, has_attr_48, not has_attr_63, has_attr_64, has_attr_69, not has_attr_80, not has_attr_82, not has_attr_93, not has_attr_96, has_attr_99, has_attr_111, has_attr_128, not has_attr_132, has_attr_145, not has_attr_148.',
#  'class(1) :- not has_attr_6, not has_attr_9, has_attr_19, has_attr_26, not has_attr_30, not has_attr_33, not has_attr_40, has_attr_44, has_attr_48, has_attr_57, has_attr_61, not has_attr_65, has_attr_70, not has_attr_74, has_attr_75, has_attr_78, has_attr_111, not has_attr_121, has_attr_123, not has_attr_125, has_attr_127, has_attr_149.',
#  'class(1) :- not has_attr_6, not has_attr_7, has_attr_9, not has_attr_17, not has_attr_18, has_attr_32, not has_attr_44, not has_attr_53, not has_attr_54, not has_attr_55, not has_attr_57, has_attr_58, has_attr_65, has_attr_75, has_attr_81, not has_attr_84, has_attr_86, not has_attr_89, not has_attr_96, has_attr_100, has_attr_109, has_attr_113, not has_attr_114, not has_attr_123, not has_attr_132, has_attr_138, has_attr_140, has_attr_141.',
#  'class(1) :- has_attr_8, has_attr_13, has_attr_14, has_attr_26, has_attr_37, has_attr_39, has_attr_48, has_attr_70, has_attr_75, has_attr_78, has_attr_89, has_attr_97, has_attr_107, has_attr_129, has_attr_131, has_attr_141, has_attr_146, has_attr_148.',
#  'class(1) :- has_attr_8, has_attr_13, has_attr_18, has_attr_28, has_attr_39, has_attr_48, has_attr_51, has_attr_70, has_attr_81, has_attr_106, has_attr_112, has_attr_124, has_attr_129, has_attr_130, has_attr_131, has_attr_138, has_attr_141, has_attr_144.',
#  'class(1) :- not has_attr_10, not has_attr_11, not has_attr_16, not has_attr_27, not has_attr_34, not has_attr_37, not has_attr_43, has_attr_49, not has_attr_64, not has_attr_71, not has_attr_74, not has_attr_81, not has_attr_87, not has_attr_100, not has_attr_105, not has_attr_118, not has_attr_120, not has_attr_122, not has_attr_127, not has_attr_131, has_attr_134, not has_attr_141, not has_attr_145, has_attr_149.',
#  'class(1) :- not has_attr_0, not has_attr_1, has_attr_4, not has_attr_5, has_attr_35, has_attr_55, has_attr_56, has_attr_65, not has_attr_72, not has_attr_78, not has_attr_86, not has_attr_104, has_attr_117, not has_attr_135, has_attr_137, not has_attr_143.',
#  'class(1) :- has_attr_0, has_attr_17, has_attr_24, has_attr_27, has_attr_30, has_attr_41, has_attr_52, not has_attr_53, not has_attr_60, not has_attr_71, has_attr_89, has_attr_93, has_attr_95, not has_attr_96, not has_attr_98, has_attr_99, has_attr_115, not has_attr_121, not has_attr_127, has_attr_130, has_attr_131, has_attr_132.',
#  'class(1) :- has_attr_3, has_attr_14, has_attr_19, has_attr_28, has_attr_33, has_attr_35, has_attr_41, has_attr_46, has_attr_65, has_attr_68, has_attr_70, has_attr_73, has_attr_75, has_attr_81, has_attr_85, has_attr_103, has_attr_105, has_attr_106, has_attr_107, has_attr_116, has_attr_120, has_attr_127, has_attr_130, has_attr_131, has_attr_140, has_attr_146.',
#  'class(1) :- has_attr_6, has_attr_14, has_attr_21, has_attr_28, has_attr_29, has_attr_37, has_attr_39, has_attr_46, has_attr_58, has_attr_67, has_attr_70, has_attr_81, has_attr_86, has_attr_91, has_attr_97, has_attr_104, has_attr_111, has_attr_118, has_attr_120, has_attr_121, has_attr_125, has_attr_127, has_attr_130.',
#  'class(2) :- has_attr_12, has_attr_23, not has_attr_35, not has_attr_39, not has_attr_53, has_attr_66, has_attr_71, has_attr_77, not has_attr_82, has_attr_93, not has_attr_101, not has_attr_103, has_attr_116, not has_attr_120, has_attr_123, not has_attr_124.',
#  'class(2) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(2) :- has_attr_4, has_attr_16, has_attr_20, has_attr_27, has_attr_37, has_attr_58, has_attr_61, has_attr_65, has_attr_66, has_attr_75, has_attr_76, has_attr_80, has_attr_97, has_attr_105, has_attr_106, has_attr_118, has_attr_128, has_attr_145.',
#  'class(2) :- has_attr_4, has_attr_7, has_attr_16, has_attr_19, has_attr_26, has_attr_39, not has_attr_43, has_attr_46, has_attr_54, has_attr_62, has_attr_66, has_attr_79, has_attr_84, has_attr_93, has_attr_97, has_attr_98, has_attr_102, has_attr_114, has_attr_116, has_attr_120, has_attr_130, has_attr_136, has_attr_147.',
#  'class(2) :- has_attr_3, has_attr_6, has_attr_14, has_attr_26, has_attr_46, has_attr_52, has_attr_56, has_attr_63, has_attr_68, not has_attr_73, has_attr_74, not has_attr_76, has_attr_90, has_attr_115, has_attr_125, has_attr_130.',
#  'class(2) :- has_attr_2, has_attr_3, not has_attr_13, not has_attr_36, has_attr_38, has_attr_43, has_attr_46, not has_attr_56, has_attr_62, has_attr_75, has_attr_95, has_attr_97, has_attr_113, has_attr_114, not has_attr_123, has_attr_125, has_attr_131, has_attr_139, has_attr_140, has_attr_142, not has_attr_147, has_attr_149.',
#  'class(2) :- has_attr_1, has_attr_7, has_attr_24, not has_attr_55, not has_attr_59, has_attr_61, has_attr_85, has_attr_90, has_attr_92, not has_attr_94, has_attr_99, not has_attr_103, has_attr_104, has_attr_106, has_attr_109, has_attr_112.',
#  'class(2) :- not has_attr_0, has_attr_4, has_attr_14, has_attr_17, not has_attr_37, has_attr_46, has_attr_48, not has_attr_63, has_attr_64, has_attr_69, not has_attr_80, not has_attr_82, not has_attr_93, not has_attr_96, has_attr_99, has_attr_111, has_attr_128, not has_attr_132, has_attr_145, not has_attr_148.',
#  'class(2) :- has_attr_5, has_attr_18, has_attr_27, has_attr_43, has_attr_44, has_attr_47, has_attr_51, has_attr_58, has_attr_61, has_attr_69, has_attr_75, has_attr_81, has_attr_91, has_attr_104, has_attr_106, has_attr_127, has_attr_130, has_attr_141, has_attr_147.',
#  'class(2) :- has_attr_5, has_attr_6, has_attr_21, has_attr_23, not has_attr_35, has_attr_66, has_attr_68, has_attr_74, has_attr_77, has_attr_91, has_attr_92, has_attr_101, has_attr_122, has_attr_142, has_attr_147.',
#  'class(2) :- has_attr_3, not has_attr_7, has_attr_9, has_attr_27, has_attr_35, not has_attr_39, has_attr_47, has_attr_51, has_attr_53, has_attr_56, has_attr_57, has_attr_77, has_attr_78, has_attr_80, has_attr_86, has_attr_124, has_attr_125, has_attr_126, has_attr_130, has_attr_135, has_attr_137, has_attr_139, has_attr_143.',
#  'class(2) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(2) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(2) :- has_attr_1, has_attr_2, has_attr_5, has_attr_8, has_attr_15, has_attr_35, has_attr_41, has_attr_43, has_attr_50, has_attr_51, has_attr_52, has_attr_55, has_attr_57, has_attr_66, has_attr_73, has_attr_75, has_attr_77, has_attr_78, has_attr_85, has_attr_109, has_attr_113, has_attr_141.',
#  'class(2) :- has_attr_3, has_attr_6, has_attr_8, has_attr_19, has_attr_27, has_attr_38, has_attr_40, has_attr_43, has_attr_48, has_attr_52, has_attr_57, has_attr_75, has_attr_78, has_attr_122, has_attr_124, has_attr_133, has_attr_135, has_attr_145, has_attr_148.',
#  'class(2) :- has_attr_0, has_attr_4, has_attr_8, has_attr_13, has_attr_18, has_attr_20, has_attr_30, has_attr_31, has_attr_43, has_attr_51, has_attr_52, has_attr_54, has_attr_55, has_attr_57, has_attr_66, has_attr_83, has_attr_94, has_attr_98, has_attr_104, has_attr_106, has_attr_118, has_attr_119, has_attr_125, has_attr_143, has_attr_149.',
#  'class(2) :- has_attr_0, has_attr_17, has_attr_24, has_attr_27, has_attr_30, has_attr_41, has_attr_52, not has_attr_53, not has_attr_60, not has_attr_71, has_attr_89, has_attr_93, has_attr_95, not has_attr_96, not has_attr_98, has_attr_99, has_attr_115, not has_attr_121, not has_attr_127, has_attr_130, has_attr_131, has_attr_132.',
#  'class(3) :- has_attr_2, has_attr_3, not has_attr_13, not has_attr_36, has_attr_38, has_attr_43, has_attr_46, not has_attr_56, has_attr_62, has_attr_75, has_attr_95, has_attr_97, has_attr_113, has_attr_114, not has_attr_123, has_attr_125, has_attr_131, has_attr_139, has_attr_140, has_attr_142, not has_attr_147, has_attr_149.',
#  'class(3) :- not has_attr_0, has_attr_4, has_attr_14, has_attr_17, not has_attr_37, has_attr_46, has_attr_48, not has_attr_63, has_attr_64, has_attr_69, not has_attr_80, not has_attr_82, not has_attr_93, not has_attr_96, has_attr_99, has_attr_111, has_attr_128, not has_attr_132, has_attr_145, not has_attr_148.',
#  'class(3) :- has_attr_5, has_attr_18, has_attr_27, has_attr_43, has_attr_44, has_attr_47, has_attr_51, has_attr_58, has_attr_61, has_attr_69, has_attr_75, has_attr_81, has_attr_91, has_attr_104, has_attr_106, has_attr_127, has_attr_130, has_attr_141, has_attr_147.',
#  'class(3) :- has_attr_3, has_attr_4, has_attr_6, has_attr_9, has_attr_10, has_attr_12, has_attr_17, has_attr_18, has_attr_27, has_attr_32, has_attr_34, has_attr_37, has_attr_38, has_attr_43, has_attr_44, has_attr_49, has_attr_50, has_attr_53, has_attr_56, has_attr_61, has_attr_64, has_attr_67, has_attr_68, has_attr_72, has_attr_73, has_attr_75, has_attr_76, has_attr_81, has_attr_86, has_attr_88, has_attr_89, has_attr_91, has_attr_95, has_attr_97, has_attr_99, has_attr_101, has_attr_103, has_attr_104, has_attr_106, has_attr_113, has_attr_122, has_attr_124, has_attr_128, has_attr_130, has_attr_131, has_attr_133, has_attr_135, has_attr_139, has_attr_141, has_attr_144, has_attr_145, has_attr_147.',
#  'class(3) :- has_attr_3, not has_attr_7, has_attr_9, has_attr_27, has_attr_35, not has_attr_39, has_attr_47, has_attr_51, has_attr_53, has_attr_56, has_attr_57, has_attr_77, has_attr_78, has_attr_80, has_attr_86, has_attr_124, has_attr_125, has_attr_126, has_attr_130, has_attr_135, has_attr_137, has_attr_139, has_attr_143.',
#  'class(3) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(3) :- not has_attr_6, not has_attr_9, has_attr_19, has_attr_26, not has_attr_30, not has_attr_33, not has_attr_40, has_attr_44, has_attr_48, has_attr_57, has_attr_61, not has_attr_65, has_attr_70, not has_attr_74, has_attr_75, has_attr_78, has_attr_111, not has_attr_121, has_attr_123, not has_attr_125, has_attr_127, has_attr_149.',
#  'class(3) :- not has_attr_17, not has_attr_45, not has_attr_54, not has_attr_55, has_attr_57, has_attr_63, not has_attr_73, not has_attr_76, has_attr_79, not has_attr_82, has_attr_84, has_attr_85, has_attr_88, not has_attr_93, not has_attr_97, has_attr_98, not has_attr_100, not has_attr_118, not has_attr_121, not has_attr_138, not has_attr_142.',
#  'class(3) :- has_attr_6, has_attr_20, not has_attr_59, has_attr_69, has_attr_82, has_attr_86, not has_attr_89, not has_attr_90, not has_attr_101, not has_attr_103, not has_attr_113, has_attr_116, has_attr_122, not has_attr_129, has_attr_144.',
#  'class(3) :- has_attr_1, not has_attr_25, has_attr_34, not has_attr_36, has_attr_50, has_attr_51, has_attr_63, has_attr_66, not has_attr_70, has_attr_73, has_attr_108, has_attr_116, has_attr_123, has_attr_129, has_attr_130, has_attr_144, has_attr_145.',
#  'class(3) :- not has_attr_1, not has_attr_3, has_attr_4, not has_attr_20, has_attr_25, not has_attr_30, not has_attr_42, not has_attr_46, not has_attr_49, has_attr_67, not has_attr_86, not has_attr_91, not has_attr_93, not has_attr_101, has_attr_108, has_attr_110, not has_attr_114, has_attr_122, not has_attr_123, not has_attr_135, not has_attr_139, not has_attr_142.',
#  'class(3) :- has_attr_2, has_attr_6, has_attr_9, has_attr_11, has_attr_27, has_attr_29, has_attr_31, has_attr_43, has_attr_47, has_attr_58, has_attr_86, has_attr_88, has_attr_93, has_attr_122, has_attr_127, has_attr_138, has_attr_141, has_attr_145.',
#  'class(4) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(4) :- has_attr_12, has_attr_23, not has_attr_35, not has_attr_39, not has_attr_53, has_attr_66, has_attr_71, has_attr_77, not has_attr_82, has_attr_93, not has_attr_101, not has_attr_103, has_attr_116, not has_attr_120, has_attr_123, not has_attr_124.',
#  'class(4) :- not has_attr_5, has_attr_14, has_attr_40, has_attr_41, has_attr_47, has_attr_52, has_attr_57, not has_attr_60, has_attr_64, has_attr_71, has_attr_78, has_attr_110, has_attr_112, has_attr_116, has_attr_127, has_attr_133, has_attr_134, has_attr_136, has_attr_142, has_attr_143.',
#  'class(4) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(4) :- not has_attr_1, not has_attr_8, not has_attr_9, not has_attr_16, has_attr_18, not has_attr_21, has_attr_62, not has_attr_81, not has_attr_86, has_attr_97, not has_attr_101, not has_attr_102, not has_attr_118.',
#  'class(4) :- has_attr_3, not has_attr_7, has_attr_9, has_attr_27, has_attr_35, not has_attr_39, has_attr_47, has_attr_51, has_attr_53, has_attr_56, has_attr_57, has_attr_77, has_attr_78, has_attr_80, has_attr_86, has_attr_124, has_attr_125, has_attr_126, has_attr_130, has_attr_135, has_attr_137, has_attr_139, has_attr_143.',
#  'class(4) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(4) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(4) :- has_attr_11, has_attr_33, has_attr_40, has_attr_41, has_attr_47, has_attr_52, has_attr_53, has_attr_57, has_attr_58, has_attr_69, has_attr_75, has_attr_77, has_attr_78, has_attr_85, has_attr_87, has_attr_119, has_attr_124, has_attr_131, has_attr_133, has_attr_134, has_attr_135, has_attr_145.',
#  'class(4) :- not has_attr_6, not has_attr_7, has_attr_9, not has_attr_17, not has_attr_18, has_attr_32, not has_attr_44, not has_attr_53, not has_attr_54, not has_attr_55, not has_attr_57, has_attr_58, has_attr_65, has_attr_75, has_attr_81, not has_attr_84, has_attr_86, not has_attr_89, not has_attr_96, has_attr_100, has_attr_109, has_attr_113, not has_attr_114, not has_attr_123, not has_attr_132, has_attr_138, has_attr_140, has_attr_141.',
#  'class(4) :- has_attr_0, has_attr_3, has_attr_22, has_attr_28, has_attr_34, has_attr_39, has_attr_42, has_attr_43, has_attr_47, has_attr_51, has_attr_52, has_attr_68, has_attr_69, has_attr_72, has_attr_75, has_attr_76, has_attr_79, has_attr_89, has_attr_90, has_attr_96, has_attr_100, has_attr_102, has_attr_104, has_attr_113, has_attr_121, has_attr_123, has_attr_141, has_attr_147.',
#  'class(4) :- not has_attr_4, has_attr_18, not has_attr_19, has_attr_29, has_attr_35, not has_attr_40, not has_attr_41, has_attr_43, not has_attr_50, not has_attr_51, has_attr_65, not has_attr_68, has_attr_71, not has_attr_72, not has_attr_75, has_attr_90, has_attr_91, has_attr_98, has_attr_112, has_attr_113, has_attr_118, has_attr_121, has_attr_129, not has_attr_131, has_attr_133, not has_attr_135, has_attr_136, has_attr_137.',
#  'class(4) :- not has_attr_4, not has_attr_5, has_attr_9, not has_attr_11, has_attr_16, not has_attr_20, has_attr_23, not has_attr_35, has_attr_49, not has_attr_56, not has_attr_57, not has_attr_62, has_attr_64, has_attr_87, not has_attr_88, not has_attr_93, not has_attr_102, not has_attr_107, not has_attr_119, not has_attr_125, not has_attr_140, has_attr_143.',
#  'class(4) :- has_attr_3, has_attr_6, has_attr_8, has_attr_19, has_attr_27, has_attr_38, has_attr_40, has_attr_43, has_attr_48, has_attr_52, has_attr_57, has_attr_75, has_attr_78, has_attr_122, has_attr_124, has_attr_133, has_attr_135, has_attr_145, has_attr_148.',
#  'class(4) :- has_attr_3, has_attr_6, has_attr_9, has_attr_11, has_attr_19, has_attr_21, has_attr_28, has_attr_30, has_attr_38, has_attr_42, has_attr_45, has_attr_47, has_attr_48, has_attr_51, has_attr_53, has_attr_64, has_attr_70, has_attr_72, has_attr_77, has_attr_83, has_attr_84, has_attr_87, has_attr_95, has_attr_100, has_attr_106, has_attr_118, has_attr_135, has_attr_141.',
#  'class(4) :- has_attr_0, has_attr_17, has_attr_24, has_attr_27, has_attr_30, has_attr_41, has_attr_52, not has_attr_53, not has_attr_60, not has_attr_71, has_attr_89, has_attr_93, has_attr_95, not has_attr_96, not has_attr_98, has_attr_99, has_attr_115, not has_attr_121, not has_attr_127, has_attr_130, has_attr_131, has_attr_132.',
#  'class(5) :- has_attr_3, has_attr_6, has_attr_14, has_attr_26, has_attr_46, has_attr_52, has_attr_56, has_attr_63, has_attr_68, not has_attr_73, has_attr_74, not has_attr_76, has_attr_90, has_attr_115, has_attr_125, has_attr_130.',
#  'class(5) :- has_attr_3, not has_attr_5, has_attr_22, has_attr_32, has_attr_45, has_attr_50, has_attr_62, has_attr_64, has_attr_72, has_attr_86, not has_attr_87, not has_attr_92, has_attr_94, has_attr_103, has_attr_119, not has_attr_127, not has_attr_131, has_attr_133, has_attr_134, has_attr_141, has_attr_148.',
#  'class(5) :- has_attr_8, has_attr_28, has_attr_29, has_attr_32, has_attr_34, has_attr_35, has_attr_44, has_attr_53, has_attr_58, has_attr_62, has_attr_64, has_attr_66, has_attr_77, has_attr_85, has_attr_91, has_attr_109, has_attr_120, has_attr_121, has_attr_128, has_attr_133, has_attr_149.',
#  'class(5) :- not has_attr_1, not has_attr_8, not has_attr_9, not has_attr_16, has_attr_18, not has_attr_21, has_attr_62, not has_attr_81, not has_attr_86, has_attr_97, not has_attr_101, not has_attr_102, not has_attr_118.',
#  'class(5) :- has_attr_5, has_attr_6, has_attr_21, has_attr_23, not has_attr_35, has_attr_66, has_attr_68, has_attr_74, has_attr_77, has_attr_91, has_attr_92, has_attr_101, has_attr_122, has_attr_142, has_attr_147.',
#  'class(5) :- has_attr_3, not has_attr_7, has_attr_9, has_attr_27, has_attr_35, not has_attr_39, has_attr_47, has_attr_51, has_attr_53, has_attr_56, has_attr_57, has_attr_77, has_attr_78, has_attr_80, has_attr_86, has_attr_124, has_attr_125, has_attr_126, has_attr_130, has_attr_135, has_attr_137, has_attr_139, has_attr_143.',
#  'class(5) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(5) :- not has_attr_6, has_attr_8, not has_attr_17, has_attr_19, has_attr_21, not has_attr_32, has_attr_35, not has_attr_39, has_attr_45, has_attr_46, not has_attr_57, not has_attr_72, not has_attr_78, not has_attr_81, not has_attr_89, has_attr_96, has_attr_112, not has_attr_127, not has_attr_130, has_attr_133, not has_attr_137, has_attr_144, has_attr_149.',
#  'class(5) :- has_attr_26, has_attr_32, has_attr_52, has_attr_53, has_attr_56, has_attr_57, has_attr_64, has_attr_71, has_attr_78, has_attr_82, has_attr_90, has_attr_111, has_attr_112, has_attr_113, has_attr_115, has_attr_118, has_attr_126, has_attr_133, has_attr_137, has_attr_139, has_attr_143, has_attr_145.',
#  'class(5) :- not has_attr_4, has_attr_18, not has_attr_19, has_attr_29, has_attr_35, not has_attr_40, not has_attr_41, has_attr_43, not has_attr_50, not has_attr_51, has_attr_65, not has_attr_68, has_attr_71, not has_attr_72, not has_attr_75, has_attr_90, has_attr_91, has_attr_98, has_attr_112, has_attr_113, has_attr_118, has_attr_121, has_attr_129, not has_attr_131, has_attr_133, not has_attr_135, has_attr_136, has_attr_137.',
#  'class(5) :- has_attr_1, not has_attr_25, has_attr_34, not has_attr_36, has_attr_50, has_attr_51, has_attr_63, has_attr_66, not has_attr_70, has_attr_73, has_attr_108, has_attr_116, has_attr_123, has_attr_129, has_attr_130, has_attr_144, has_attr_145.',
#  'class(5) :- has_attr_6, has_attr_8, has_attr_24, has_attr_28, has_attr_34, has_attr_39, has_attr_43, has_attr_53, has_attr_62, has_attr_63, has_attr_67, has_attr_77, has_attr_90, has_attr_92, has_attr_97, has_attr_103, has_attr_109, has_attr_113, has_attr_120, has_attr_121, has_attr_133, has_attr_134, has_attr_136.',
#  'class(5) :- has_attr_6, has_attr_14, has_attr_21, has_attr_28, has_attr_29, has_attr_37, has_attr_39, has_attr_46, has_attr_58, has_attr_67, has_attr_70, has_attr_81, has_attr_86, has_attr_91, has_attr_97, has_attr_104, has_attr_111, has_attr_118, has_attr_120, has_attr_121, has_attr_125, has_attr_127, has_attr_130.',
#  'class(6) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(6) :- has_attr_12, has_attr_23, not has_attr_35, not has_attr_39, not has_attr_53, has_attr_66, has_attr_71, has_attr_77, not has_attr_82, has_attr_93, not has_attr_101, not has_attr_103, has_attr_116, not has_attr_120, has_attr_123, not has_attr_124.',
#  'class(6) :- has_attr_4, has_attr_7, has_attr_16, has_attr_19, has_attr_26, has_attr_39, not has_attr_43, has_attr_46, has_attr_54, has_attr_62, has_attr_66, has_attr_79, has_attr_84, has_attr_93, has_attr_97, has_attr_98, has_attr_102, has_attr_114, has_attr_116, has_attr_120, has_attr_130, has_attr_136, has_attr_147.',
#  'class(6) :- has_attr_3, has_attr_6, has_attr_14, has_attr_26, has_attr_46, has_attr_52, has_attr_56, has_attr_63, has_attr_68, not has_attr_73, has_attr_74, not has_attr_76, has_attr_90, has_attr_115, has_attr_125, has_attr_130.',
#  'class(6) :- has_attr_0, has_attr_5, has_attr_6, has_attr_9, has_attr_13, has_attr_22, has_attr_27, has_attr_37, has_attr_44, has_attr_49, has_attr_51, has_attr_55, has_attr_61, has_attr_70, has_attr_72, has_attr_81, has_attr_86, has_attr_87, has_attr_88, has_attr_94, has_attr_96, has_attr_102, has_attr_103, has_attr_106, has_attr_113, has_attr_120, has_attr_125, has_attr_129, has_attr_131.',
#  'class(6) :- not has_attr_1, not has_attr_8, not has_attr_9, not has_attr_16, has_attr_18, not has_attr_21, has_attr_62, not has_attr_81, not has_attr_86, has_attr_97, not has_attr_101, not has_attr_102, not has_attr_118.',
#  'class(6) :- has_attr_18, has_attr_20, has_attr_27, has_attr_31, has_attr_38, has_attr_42, has_attr_47, has_attr_53, has_attr_64, has_attr_76, has_attr_77, has_attr_82, has_attr_87, has_attr_94, has_attr_112, has_attr_118, has_attr_130, has_attr_136, has_attr_143.',
#  'class(6) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(6) :- not has_attr_6, not has_attr_9, has_attr_19, has_attr_26, not has_attr_30, not has_attr_33, not has_attr_40, has_attr_44, has_attr_48, has_attr_57, has_attr_61, not has_attr_65, has_attr_70, not has_attr_74, has_attr_75, has_attr_78, has_attr_111, not has_attr_121, has_attr_123, not has_attr_125, has_attr_127, has_attr_149.',
#  'class(6) :- has_attr_1, has_attr_3, has_attr_5, has_attr_9, has_attr_14, has_attr_18, has_attr_31, has_attr_38, has_attr_53, has_attr_56, has_attr_61, has_attr_63, has_attr_84, has_attr_91, has_attr_95, has_attr_96, has_attr_98, has_attr_113, has_attr_120, has_attr_129, has_attr_130, has_attr_135.',
#  'class(6) :- has_attr_8, has_attr_13, has_attr_18, has_attr_28, has_attr_39, has_attr_48, has_attr_51, has_attr_70, has_attr_81, has_attr_106, has_attr_112, has_attr_124, has_attr_129, has_attr_130, has_attr_131, has_attr_138, has_attr_141, has_attr_144.',
#  'class(6) :- not has_attr_10, not has_attr_11, not has_attr_16, not has_attr_27, not has_attr_34, not has_attr_37, not has_attr_43, has_attr_49, not has_attr_64, not has_attr_71, not has_attr_74, not has_attr_81, not has_attr_87, not has_attr_100, not has_attr_105, not has_attr_118, not has_attr_120, not has_attr_122, not has_attr_127, not has_attr_131, has_attr_134, not has_attr_141, not has_attr_145, has_attr_149.',
#  'class(6) :- not has_attr_4, not has_attr_5, has_attr_9, not has_attr_11, has_attr_16, not has_attr_20, has_attr_23, not has_attr_35, has_attr_49, not has_attr_56, not has_attr_57, not has_attr_62, has_attr_64, has_attr_87, not has_attr_88, not has_attr_93, not has_attr_102, not has_attr_107, not has_attr_119, not has_attr_125, not has_attr_140, has_attr_143.',
#  'class(6) :- has_attr_0, not has_attr_2, has_attr_6, has_attr_13, not has_attr_26, has_attr_29, has_attr_55, not has_attr_65, not has_attr_69, has_attr_72, has_attr_79, not has_attr_100, has_attr_111, not has_attr_115, has_attr_118, not has_attr_121, has_attr_131, has_attr_137.',
#  'class(6) :- has_attr_3, has_attr_6, has_attr_9, has_attr_11, has_attr_19, has_attr_21, has_attr_28, has_attr_30, has_attr_38, has_attr_42, has_attr_45, has_attr_47, has_attr_48, has_attr_51, has_attr_53, has_attr_64, has_attr_70, has_attr_72, has_attr_77, has_attr_83, has_attr_84, has_attr_87, has_attr_95, has_attr_100, has_attr_106, has_attr_118, has_attr_135, has_attr_141.',
#  'class(7) :- not has_attr_5, has_attr_14, has_attr_40, has_attr_41, has_attr_47, has_attr_52, has_attr_57, not has_attr_60, has_attr_64, has_attr_71, has_attr_78, has_attr_110, has_attr_112, has_attr_116, has_attr_127, has_attr_133, has_attr_134, has_attr_136, has_attr_142, has_attr_143.',
#  'class(7) :- not has_attr_0, has_attr_4, has_attr_14, has_attr_17, not has_attr_37, has_attr_46, has_attr_48, not has_attr_63, has_attr_64, has_attr_69, not has_attr_80, not has_attr_82, not has_attr_93, not has_attr_96, has_attr_99, has_attr_111, has_attr_128, not has_attr_132, has_attr_145, not has_attr_148.',
#  'class(7) :- not has_attr_1, not has_attr_8, not has_attr_9, not has_attr_16, has_attr_18, not has_attr_21, has_attr_62, not has_attr_81, not has_attr_86, has_attr_97, not has_attr_101, not has_attr_102, not has_attr_118.',
#  'class(7) :- has_attr_18, has_attr_20, has_attr_27, has_attr_31, has_attr_38, has_attr_42, has_attr_47, has_attr_53, has_attr_64, has_attr_76, has_attr_77, has_attr_82, has_attr_87, has_attr_94, has_attr_112, has_attr_118, has_attr_130, has_attr_136, has_attr_143.',
#  'class(7) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(7) :- not has_attr_6, has_attr_8, not has_attr_17, has_attr_19, has_attr_21, not has_attr_32, has_attr_35, not has_attr_39, has_attr_45, has_attr_46, not has_attr_57, not has_attr_72, not has_attr_78, not has_attr_81, not has_attr_89, has_attr_96, has_attr_112, not has_attr_127, not has_attr_130, has_attr_133, not has_attr_137, has_attr_144, has_attr_149.',
#  'class(7) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(7) :- has_attr_11, has_attr_33, has_attr_40, has_attr_41, has_attr_47, has_attr_52, has_attr_53, has_attr_57, has_attr_58, has_attr_69, has_attr_75, has_attr_77, has_attr_78, has_attr_85, has_attr_87, has_attr_119, has_attr_124, has_attr_131, has_attr_133, has_attr_134, has_attr_135, has_attr_145.',
#  'class(7) :- has_attr_7, has_attr_20, has_attr_21, has_attr_24, has_attr_31, has_attr_51, has_attr_64, has_attr_79, has_attr_81, has_attr_89, has_attr_90, has_attr_113, has_attr_116, has_attr_119, has_attr_120, has_attr_121, has_attr_123, has_attr_135, has_attr_136, has_attr_147.',
#  'class(7) :- has_attr_26, has_attr_32, has_attr_52, has_attr_53, has_attr_56, has_attr_57, has_attr_64, has_attr_71, has_attr_78, has_attr_82, has_attr_90, has_attr_111, has_attr_112, has_attr_113, has_attr_115, has_attr_118, has_attr_126, has_attr_133, has_attr_137, has_attr_139, has_attr_143, has_attr_145.',
#  'class(7) :- not has_attr_4, not has_attr_5, has_attr_9, not has_attr_11, has_attr_16, not has_attr_20, has_attr_23, not has_attr_35, has_attr_49, not has_attr_56, not has_attr_57, not has_attr_62, has_attr_64, has_attr_87, not has_attr_88, not has_attr_93, not has_attr_102, not has_attr_107, not has_attr_119, not has_attr_125, not has_attr_140, has_attr_143.',
#  'class(7) :- has_attr_1, not has_attr_25, has_attr_34, not has_attr_36, has_attr_50, has_attr_51, has_attr_63, has_attr_66, not has_attr_70, has_attr_73, has_attr_108, has_attr_116, has_attr_123, has_attr_129, has_attr_130, has_attr_144, has_attr_145.',
#  'class(7) :- not has_attr_0, not has_attr_1, has_attr_4, not has_attr_5, has_attr_35, has_attr_55, has_attr_56, has_attr_65, not has_attr_72, not has_attr_78, not has_attr_86, not has_attr_104, has_attr_117, not has_attr_135, has_attr_137, not has_attr_143.',
#  'class(7) :- has_attr_2, has_attr_6, has_attr_9, has_attr_11, has_attr_27, has_attr_29, has_attr_31, has_attr_43, has_attr_47, has_attr_58, has_attr_86, has_attr_88, has_attr_93, has_attr_122, has_attr_127, has_attr_138, has_attr_141, has_attr_145.',
#  'class(8) :- has_attr_12, has_attr_23, not has_attr_35, not has_attr_39, not has_attr_53, has_attr_66, has_attr_71, has_attr_77, not has_attr_82, has_attr_93, not has_attr_101, not has_attr_103, has_attr_116, not has_attr_120, has_attr_123, not has_attr_124.',
#  'class(8) :- has_attr_1, has_attr_3, has_attr_4, has_attr_6, has_attr_15, has_attr_16, has_attr_20, has_attr_21, has_attr_24, has_attr_25, has_attr_39, has_attr_46, has_attr_49, has_attr_63, has_attr_79, has_attr_82, has_attr_84, has_attr_86, has_attr_96, has_attr_102, has_attr_103, has_attr_110, has_attr_119, has_attr_120, has_attr_121, has_attr_125, has_attr_126, has_attr_128, has_attr_134, has_attr_135, has_attr_136, has_attr_147.',
#  'class(8) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(8) :- has_attr_4, has_attr_16, has_attr_20, has_attr_27, has_attr_37, has_attr_58, has_attr_61, has_attr_65, has_attr_66, has_attr_75, has_attr_76, has_attr_80, has_attr_97, has_attr_105, has_attr_106, has_attr_118, has_attr_128, has_attr_145.',
#  'class(8) :- has_attr_4, has_attr_7, has_attr_16, has_attr_19, has_attr_26, has_attr_39, not has_attr_43, has_attr_46, has_attr_54, has_attr_62, has_attr_66, has_attr_79, has_attr_84, has_attr_93, has_attr_97, has_attr_98, has_attr_102, has_attr_114, has_attr_116, has_attr_120, has_attr_130, has_attr_136, has_attr_147.',
#  'class(8) :- has_attr_3, not has_attr_5, has_attr_22, has_attr_32, has_attr_45, has_attr_50, has_attr_62, has_attr_64, has_attr_72, has_attr_86, not has_attr_87, not has_attr_92, has_attr_94, has_attr_103, has_attr_119, not has_attr_127, not has_attr_131, has_attr_133, has_attr_134, has_attr_141, has_attr_148.',
#  'class(8) :- has_attr_1, has_attr_7, has_attr_24, not has_attr_55, not has_attr_59, has_attr_61, has_attr_85, has_attr_90, has_attr_92, not has_attr_94, has_attr_99, not has_attr_103, has_attr_104, has_attr_106, has_attr_109, has_attr_112.',
#  'class(8) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(8) :- not has_attr_6, has_attr_8, not has_attr_17, has_attr_19, has_attr_21, not has_attr_32, has_attr_35, not has_attr_39, has_attr_45, has_attr_46, not has_attr_57, not has_attr_72, not has_attr_78, not has_attr_81, not has_attr_89, has_attr_96, has_attr_112, not has_attr_127, not has_attr_130, has_attr_133, not has_attr_137, has_attr_144, has_attr_149.',
#  'class(8) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(8) :- has_attr_3, has_attr_7, has_attr_9, has_attr_14, has_attr_16, has_attr_20, has_attr_22, has_attr_23, has_attr_27, has_attr_32, has_attr_34, has_attr_39, has_attr_49, has_attr_73, has_attr_92, has_attr_98, has_attr_105, has_attr_112, has_attr_116, has_attr_122, has_attr_136, has_attr_143.',
#  'class(8) :- has_attr_7, has_attr_20, has_attr_21, has_attr_24, has_attr_31, has_attr_51, has_attr_64, has_attr_79, has_attr_81, has_attr_89, has_attr_90, has_attr_113, has_attr_116, has_attr_119, has_attr_120, has_attr_121, has_attr_123, has_attr_135, has_attr_136, has_attr_147.',
#  'class(8) :- has_attr_6, has_attr_20, not has_attr_59, has_attr_69, has_attr_82, has_attr_86, not has_attr_89, not has_attr_90, not has_attr_101, not has_attr_103, not has_attr_113, has_attr_116, has_attr_122, not has_attr_129, has_attr_144.',
#  'class(8) :- not has_attr_10, not has_attr_11, not has_attr_16, not has_attr_27, not has_attr_34, not has_attr_37, not has_attr_43, has_attr_49, not has_attr_64, not has_attr_71, not has_attr_74, not has_attr_81, not has_attr_87, not has_attr_100, not has_attr_105, not has_attr_118, not has_attr_120, not has_attr_122, not has_attr_127, not has_attr_131, has_attr_134, not has_attr_141, not has_attr_145, has_attr_149.',
#  'class(9) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(9) :- not has_attr_6, has_attr_8, has_attr_12, not has_attr_13, not has_attr_14, has_attr_17, has_attr_28, has_attr_35, has_attr_67, has_attr_70, has_attr_75, has_attr_79, has_attr_85, has_attr_103, has_attr_112, has_attr_120, has_attr_129, has_attr_138, has_attr_139, not has_attr_143, has_attr_147.',
#  'class(9) :- not has_attr_1, not has_attr_8, not has_attr_9, not has_attr_16, has_attr_18, not has_attr_21, has_attr_62, not has_attr_81, not has_attr_86, has_attr_97, not has_attr_101, not has_attr_102, not has_attr_118.',
#  'class(9) :- not has_attr_6, not has_attr_9, has_attr_19, has_attr_26, not has_attr_30, not has_attr_33, not has_attr_40, has_attr_44, has_attr_48, has_attr_57, has_attr_61, not has_attr_65, has_attr_70, not has_attr_74, has_attr_75, has_attr_78, has_attr_111, not has_attr_121, has_attr_123, not has_attr_125, has_attr_127, has_attr_149.',
#  'class(9) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(9) :- has_attr_1, has_attr_2, has_attr_5, has_attr_8, has_attr_15, has_attr_35, has_attr_41, has_attr_43, has_attr_50, has_attr_51, has_attr_52, has_attr_55, has_attr_57, has_attr_66, has_attr_73, has_attr_75, has_attr_77, has_attr_78, has_attr_85, has_attr_109, has_attr_113, has_attr_141.',
#  'class(9) :- has_attr_6, has_attr_20, not has_attr_59, has_attr_69, has_attr_82, has_attr_86, not has_attr_89, not has_attr_90, not has_attr_101, not has_attr_103, not has_attr_113, has_attr_116, has_attr_122, not has_attr_129, has_attr_144.',
#  'class(9) :- not has_attr_4, not has_attr_5, has_attr_9, not has_attr_11, has_attr_16, not has_attr_20, has_attr_23, not has_attr_35, has_attr_49, not has_attr_56, not has_attr_57, not has_attr_62, has_attr_64, has_attr_87, not has_attr_88, not has_attr_93, not has_attr_102, not has_attr_107, not has_attr_119, not has_attr_125, not has_attr_140, has_attr_143.',
#  'class(9) :- has_attr_1, not has_attr_25, has_attr_34, not has_attr_36, has_attr_50, has_attr_51, has_attr_63, has_attr_66, not has_attr_70, has_attr_73, has_attr_108, has_attr_116, has_attr_123, has_attr_129, has_attr_130, has_attr_144, has_attr_145.',
#  'class(9) :- has_attr_12, has_attr_15, has_attr_22, has_attr_29, has_attr_34, has_attr_44, has_attr_51, has_attr_54, has_attr_55, has_attr_57, has_attr_59, has_attr_72, has_attr_78, has_attr_79, has_attr_87, has_attr_96, has_attr_101, has_attr_106, has_attr_113, has_attr_116, has_attr_123, has_attr_125, has_attr_129, has_attr_144, has_attr_147.',
#  'class(9) :- not has_attr_0, not has_attr_1, has_attr_4, not has_attr_5, has_attr_35, has_attr_55, has_attr_56, has_attr_65, not has_attr_72, not has_attr_78, not has_attr_86, not has_attr_104, has_attr_117, not has_attr_135, has_attr_137, not has_attr_143.',
#  'class(9) :- has_attr_15, has_attr_26, has_attr_28, has_attr_29, has_attr_43, has_attr_49, has_attr_51, has_attr_52, has_attr_56, has_attr_66, has_attr_82, has_attr_94, has_attr_100, has_attr_114, has_attr_122, has_attr_123, has_attr_127, has_attr_128, has_attr_147.',
#  'class(10) :- not has_attr_6, has_attr_8, has_attr_12, not has_attr_13, not has_attr_14, has_attr_17, has_attr_28, has_attr_35, has_attr_67, has_attr_70, has_attr_75, has_attr_79, has_attr_85, has_attr_103, has_attr_112, has_attr_120, has_attr_129, has_attr_138, has_attr_139, not has_attr_143, has_attr_147.',
# ...
#  'class(21) :- has_attr_6, has_attr_8, has_attr_24, has_attr_28, has_attr_34, has_attr_39, has_attr_43, has_attr_53, has_attr_62, has_attr_63, has_attr_67, has_attr_77, has_attr_90, has_attr_92, has_attr_97, has_attr_103, has_attr_109, has_attr_113, has_attr_120, has_attr_121, has_attr_133, has_attr_134, has_attr_136.',
#  'class(22) :- has_attr_2, has_attr_3, has_attr_12, has_attr_17, has_attr_18, has_attr_29, has_attr_39, has_attr_65, has_attr_76, has_attr_85, has_attr_88, has_attr_91, has_attr_111, has_attr_112, has_attr_116, has_attr_120, has_attr_122, has_attr_124.',
#  'class(22) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(22) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(22) :- not has_attr_0, has_attr_4, has_attr_14, has_attr_17, not has_attr_37, has_attr_46, has_attr_48, not has_attr_63, has_attr_64, has_attr_69, not has_attr_80, not has_attr_82, not has_attr_93, not has_attr_96, has_attr_99, has_attr_111, has_attr_128, not has_attr_132, has_attr_145, not has_attr_148.',
#  'class(22) :- has_attr_8, has_attr_28, has_attr_29, has_attr_32, has_attr_34, has_attr_35, has_attr_44, has_attr_53, has_attr_58, has_attr_62, has_attr_64, has_attr_66, has_attr_77, has_attr_85, has_attr_91, has_attr_109, has_attr_120, has_attr_121, has_attr_128, has_attr_133, has_attr_149.',
#  'class(22) :- has_attr_1, has_attr_8, has_attr_15, has_attr_19, has_attr_23, has_attr_27, has_attr_28, has_attr_31, has_attr_33, has_attr_45, has_attr_50, has_attr_58, has_attr_61, has_attr_69, has_attr_74, has_attr_77, has_attr_83, has_attr_84, has_attr_89, has_attr_97, has_attr_100, has_attr_104, has_attr_108, has_attr_117, has_attr_122, has_attr_127, has_attr_130, has_attr_134, has_attr_140, has_attr_146, has_attr_148.',
#  'class(22) :- has_attr_5, has_attr_6, has_attr_21, has_attr_23, not has_attr_35, has_attr_66, has_attr_68, has_attr_74, has_attr_77, has_attr_91, has_attr_92, has_attr_101, has_attr_122, has_attr_142, has_attr_147.',
#  'class(22) :- has_attr_18, has_attr_20, has_attr_27, has_attr_31, has_attr_38, has_attr_42, has_attr_47, has_attr_53, has_attr_64, has_attr_76, has_attr_77, has_attr_82, has_attr_87, has_attr_94, has_attr_112, has_attr_118, has_attr_130, has_attr_136, has_attr_143.',
#  'class(22) :- not has_attr_6, has_attr_8, not has_attr_17, has_attr_19, has_attr_21, not has_attr_32, has_attr_35, not has_attr_39, has_attr_45, has_attr_46, not has_attr_57, not has_attr_72, not has_attr_78, not has_attr_81, not has_attr_89, has_attr_96, has_attr_112, not has_attr_127, not has_attr_130, has_attr_133, not has_attr_137, has_attr_144, has_attr_149.',
#  'class(22) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(22) :- has_attr_6, has_attr_20, not has_attr_59, has_attr_69, has_attr_82, has_attr_86, not has_attr_89, not has_attr_90, not has_attr_101, not has_attr_103, not has_attr_113, has_attr_116, has_attr_122, not has_attr_129, has_attr_144.',
#  'class(22) :- not has_attr_4, not has_attr_5, has_attr_9, not has_attr_11, has_attr_16, not has_attr_20, has_attr_23, not has_attr_35, has_attr_49, not has_attr_56, not has_attr_57, not has_attr_62, has_attr_64, has_attr_87, not has_attr_88, not has_attr_93, not has_attr_102, not has_attr_107, not has_attr_119, not has_attr_125, not has_attr_140, has_attr_143.',
#  'class(22) :- has_attr_1, not has_attr_25, has_attr_34, not has_attr_36, has_attr_50, has_attr_51, has_attr_63, has_attr_66, not has_attr_70, has_attr_73, has_attr_108, has_attr_116, has_attr_123, has_attr_129, has_attr_130, has_attr_144, has_attr_145.',
#  'class(22) :- not has_attr_1, not has_attr_3, has_attr_4, not has_attr_20, has_attr_25, not has_attr_30, not has_attr_42, not has_attr_46, not has_attr_49, has_attr_67, not has_attr_86, not has_attr_91, not has_attr_93, not has_attr_101, has_attr_108, has_attr_110, not has_attr_114, has_attr_122, not has_attr_123, not has_attr_135, not has_attr_139, not has_attr_142.',
#  'class(22) :- not has_attr_0, not has_attr_1, has_attr_4, not has_attr_5, has_attr_35, has_attr_55, has_attr_56, has_attr_65, not has_attr_72, not has_attr_78, not has_attr_86, not has_attr_104, has_attr_117, not has_attr_135, has_attr_137, not has_attr_143.',
#  'class(22) :- has_attr_8, has_attr_15, has_attr_17, has_attr_18, has_attr_32, has_attr_39, has_attr_42, has_attr_52, has_attr_53, has_attr_57, has_attr_59, has_attr_62, has_attr_63, has_attr_74, has_attr_76, has_attr_82, has_attr_96, has_attr_97, has_attr_100, has_attr_109, has_attr_121, has_attr_122, has_attr_126, has_attr_129, has_attr_140, has_attr_145, has_attr_149.',
#  'class(23) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(23) :- not has_attr_12, has_attr_25, not has_attr_26, not has_attr_31, not has_attr_33, not has_attr_36, not has_attr_48, not has_attr_54, not has_attr_58, not has_attr_67, not has_attr_75, not has_attr_81, has_attr_82, not has_attr_97, has_attr_100, not has_attr_101, not has_attr_106, not has_attr_107, has_attr_115, has_attr_119, not has_attr_124, not has_attr_126, has_attr_131, not has_attr_138, has_attr_149.',
#  'class(23) :- not has_attr_6, has_attr_8, has_attr_12, not has_attr_13, not has_attr_14, has_attr_17, has_attr_28, has_attr_35, has_attr_67, has_attr_70, has_attr_75, has_attr_79, has_attr_85, has_attr_103, has_attr_112, has_attr_120, has_attr_129, has_attr_138, has_attr_139, not has_attr_143, has_attr_147.',
#  'class(23) :- has_attr_3, not has_attr_5, has_attr_22, has_attr_32, has_attr_45, has_attr_50, has_attr_62, has_attr_64, has_attr_72, has_attr_86, not has_attr_87, not has_attr_92, has_attr_94, has_attr_103, has_attr_119, not has_attr_127, not has_attr_131, has_attr_133, has_attr_134, has_attr_141, has_attr_148.',
#  'class(23) :- has_attr_4, has_attr_7, has_attr_8, has_attr_12, has_attr_15, has_attr_17, has_attr_23, has_attr_26, has_attr_27, has_attr_28, has_attr_29, has_attr_35, has_attr_36, has_attr_37, has_attr_38, has_attr_43, has_attr_45, has_attr_46, has_attr_47, has_attr_52, has_attr_53, has_attr_59, has_attr_63, has_attr_68, has_attr_79, has_attr_80, has_attr_83, has_attr_93, has_attr_95, has_attr_96, has_attr_97, has_attr_102, has_attr_103, has_attr_111, has_attr_112, has_attr_123, has_attr_127, has_attr_129, has_attr_132, has_attr_142, has_attr_144, has_attr_147, has_attr_149.',
#  'class(23) :- not has_attr_6, has_attr_8, not has_attr_17, has_attr_19, has_attr_21, not has_attr_32, has_attr_35, not has_attr_39, has_attr_45, has_attr_46, not has_attr_57, not has_attr_72, not has_attr_78, not has_attr_81, not has_attr_89, has_attr_96, has_attr_112, not has_attr_127, not has_attr_130, has_attr_133, not has_attr_137, has_attr_144, has_attr_149.',
#  'class(23) :- not has_attr_0, not has_attr_1, has_attr_9, not has_attr_16, not has_attr_27, has_attr_30, not has_attr_35, has_attr_43, not has_attr_45, has_attr_50, has_attr_55, not has_attr_56, has_attr_66, not has_attr_70, has_attr_71, not has_attr_76, not has_attr_81, not has_attr_86, has_attr_93, not has_attr_94, not has_attr_105, has_attr_106, has_attr_112, not has_attr_117, not has_attr_120, not has_attr_121, has_attr_128, has_attr_130, not has_attr_139, not has_attr_146.',
#  'class(23) :- not has_attr_18, not has_attr_26, has_attr_27, not has_attr_28, not has_attr_32, not has_attr_41, has_attr_44, has_attr_50, not has_attr_56, not has_attr_57, not has_attr_58, not has_attr_64, not has_attr_70, has_attr_79, not has_attr_81, has_attr_83, has_attr_96, has_attr_98, has_attr_102, has_attr_103, not has_attr_107, not has_attr_108, not has_attr_112, has_attr_114, has_attr_116, not has_attr_117, has_attr_127, not has_attr_129, has_attr_140, not has_attr_141, not has_attr_147, has_attr_149.',
#  'class(23) :- has_attr_0, has_attr_19, has_attr_26, has_attr_36, has_attr_38, has_attr_40, has_attr_43, has_attr_49, has_attr_52, has_attr_66, has_attr_79, has_attr_80, has_attr_83, has_attr_90, has_attr_95, has_attr_98, has_attr_99, has_attr_114, has_attr_115, has_attr_120, has_attr_121, has_attr_127, has_attr_128, has_attr_129, has_attr_132, has_attr_133, has_attr_142, has_attr_148.',
#  'class(23) :- not has_attr_6, not has_attr_7, has_attr_9, not has_attr_17, not has_attr_18, has_attr_32, not has_attr_44, not has_attr_53, not has_attr_54, not has_attr_55, not has_attr_57, has_attr_58, has_attr_65, has_attr_75, has_attr_81, not has_attr_84, has_attr_86, not has_attr_89, not has_attr_96, has_attr_100, has_attr_109, has_attr_113, not has_attr_114, not has_attr_123, not has_attr_132, has_attr_138, has_attr_140, has_attr_141.',
#  'class(23) :- not has_attr_10, not has_attr_11, not has_attr_16, not has_attr_27, not has_attr_34, not has_attr_37, not has_attr_43, has_attr_49, not has_attr_64, not has_attr_71, not has_attr_74, not has_attr_81, not has_attr_87, not has_attr_100, not has_attr_105, not has_attr_118, not has_attr_120, not has_attr_122, not has_attr_127, not has_attr_131, has_attr_134, not has_attr_141, not has_attr_145, has_attr_149.',
#  'class(23) :- not has_attr_0, not has_attr_1, has_attr_4, not has_attr_5, has_attr_35, has_attr_55, has_attr_56, has_attr_65, not has_attr_72, not has_attr_78, not has_attr_86, not has_attr_104, has_attr_117, not has_attr_135, has_attr_137, not has_attr_143.',
#  'class(23) :- has_attr_15, has_attr_26, has_attr_28, has_attr_29, has_attr_43, has_attr_49, has_attr_51, has_attr_52, has_attr_56, has_attr_66, has_attr_82, has_attr_94, has_attr_100, has_attr_114, has_attr_122, has_attr_123, has_attr_127, has_attr_128, has_attr_147.',
#  'class(24) :- has_attr_0, has_attr_5, has_attr_8, has_attr_13, has_attr_28, has_attr_41, has_attr_52, has_attr_63, has_attr_78, not has_attr_81, has_attr_83, has_attr_87, has_attr_117, has_attr_121, not has_attr_126, has_attr_131, not has_attr_140, has_attr_141, not has_attr_147.',
#  'class(24) :- has_attr_12, has_attr_23, not has_attr_35, not has_attr_39, not has_attr_53, has_attr_66, has_attr_71, has_attr_77, not has_attr_82, has_attr_93, not has_attr_101, not has_attr_103, has_attr_116, not has_attr_120, has_attr_123, not has_attr_124.',
#  'class(24) :- has_attr_2, has_attr_3, not has_attr_13, not has_attr_36, has_attr_38, has_attr_43, has_attr_46, not has_attr_56, has_attr_62, has_attr_75, has_attr_95, has_attr_97, has_attr_113, has_attr_114, not has_attr_123, has_attr_125, has_attr_131, has_attr_139, has_attr_140, has_attr_142, not has_attr_147, has_attr_149.',
#  'class(24) :- has_attr_3, not has_attr_5, has_attr_22, has_attr_32, has_attr_45, has_attr_50, has_attr_62, has_attr_64, has_attr_72, has_attr_86, not has_attr_87, not has_attr_92, has_attr_94, has_attr_103, has_attr_119, not has_attr_127, not has_attr_131, has_attr_133, has_attr_134, has_attr_141, has_attr_148.',
#  'class(24) :- has_attr_1, has_attr_7, has_attr_24, not has_attr_55, not has_attr_59, has_attr_61, has_attr_85, has_attr_90, has_attr_92, not has_attr_94, has_attr_99, not has_attr_103, has_attr_104, has_attr_106, has_attr_109, has_attr_112.',
#  'class(24) :- not has_attr_0, has_attr_4, has_attr_14, has_attr_17, not has_attr_37, has_attr_46, has_attr_48, not has_attr_63, has_attr_64, has_attr_69, not has_attr_80, not has_attr_82, not has_attr_93, not has_attr_96, has_attr_99, has_attr_111, has_attr_128, not has_attr_132, has_attr_145, not has_attr_148.',
#  'class(24) :- not has_attr_8, not has_attr_11, not has_attr_14, not has_attr_15, not has_attr_18, not has_attr_22, has_attr_27, has_attr_32, not has_attr_40, not has_attr_41, not has_attr_53, not has_attr_61, not has_attr_75, has_attr_77, not has_attr_82, not has_attr_83, has_attr_93, has_attr_95, not has_attr_118, not has_attr_141.',
#  'class(24) :- not has_attr_6, not has_attr_9, has_attr_19, has_attr_26, not has_attr_30, not has_attr_33, not has_attr_40, has_attr_44, has_attr_48, has_attr_57, has_attr_61, not has_attr_65, has_attr_70, not has_attr_74, has_attr_75, has_attr_78, has_attr_111, not has_attr_121, has_attr_123, not has_attr_125, has_attr_127, has_attr_149.',
#  'class(24) :- has_attr_3, has_attr_7, has_attr_9, has_attr_14, has_attr_16, has_attr_20, has_attr_22, has_attr_23, has_attr_27, has_attr_32, has_attr_34, has_attr_39, has_attr_49, has_attr_73, has_attr_92, has_attr_98, has_attr_105, has_attr_112, has_attr_116, has_attr_122, has_attr_136, has_attr_143.',
#  'class(24) :- has_attr_8, has_attr_13, has_attr_14, has_attr_26, has_attr_37, has_attr_39, has_attr_48, has_attr_70, has_attr_75, has_attr_78, has_attr_89, has_attr_97, has_attr_107, has_attr_129, has_attr_131, has_attr_141, has_attr_146, has_attr_148.',
#  'class(24) :- has_attr_1, has_attr_2, has_attr_5, has_attr_8, has_attr_15, has_attr_35, has_attr_41, has_attr_43, has_attr_50, has_attr_51, has_attr_52, has_attr_55, has_attr_57, has_attr_66, has_attr_73, has_attr_75, has_attr_77, has_attr_78, has_attr_85, has_attr_109, has_attr_113, has_attr_141.',
#  'class(24) :- has_attr_0, has_attr_3, has_attr_22, has_attr_28, has_attr_34, has_attr_39, has_attr_42, has_attr_43, has_attr_47, has_attr_51, has_attr_52, has_attr_68, has_attr_69, has_attr_72, has_attr_75, has_attr_76, has_attr_79, has_attr_89, has_attr_90, has_attr_96, has_attr_100, has_attr_102, has_attr_104, has_attr_113, has_attr_121, has_attr_123, has_attr_141, has_attr_147.',
#  'class(24) :- not has_attr_10, not has_attr_11, not has_attr_16, not has_attr_27, not has_attr_34, not has_attr_37, not has_attr_43, has_attr_49, not has_attr_64, not has_attr_71, not has_attr_74, not has_attr_81, not has_attr_87, not has_attr_100, not has_attr_105, not has_attr_118, not has_attr_120, not has_attr_122, not has_attr_127, not has_attr_131, has_attr_134, not has_attr_141, not has_attr_145, has_attr_149.',
#  'class(24) :- not has_attr_0, not has_attr_1, has_attr_4, not has_attr_5, has_attr_35, has_attr_55, has_attr_56, has_attr_65, not has_attr_72, not has_attr_78, not has_attr_86, not has_attr_104, has_attr_117, not has_attr_135, has_attr_137, not has_attr_143.',
#  'class(24) :- has_attr_0, has_attr_17, has_attr_24, has_attr_27, has_attr_30, has_attr_41, has_attr_52, not has_attr_53, not has_attr_60, not has_attr_71, has_attr_89, has_attr_93, has_attr_95, not has_attr_96, not has_attr_98, has_attr_99, has_attr_115, not has_attr_121, not has_attr_127, has_attr_130, has_attr_131, has_attr_132.',
#  'class(24) :- has_attr_2, has_attr_3, has_attr_5, has_attr_9, has_attr_15, has_attr_16, has_attr_19, has_attr_27, has_attr_31, has_attr_37, has_attr_38, has_attr_45, has_attr_48, has_attr_55, has_attr_57, has_attr_58, has_attr_70, has_attr_72, has_attr_80, has_attr_86, has_attr_97, has_attr_104, has_attr_107, has_attr_108, has_attr_115, has_attr_131, has_attr_137, has_attr_148.']

# %%
dnpz['rule_str']
# Out:
# array(['c0 :- a0, a2, a6, a7, a8, a10, a13, a14, a16, a17, a19, a24, a27, a28, a32, a33, a34, a37, a41, a42, a44, a46, a49, a51, a56, a57, a58, a62, a67, a68, a69, a71, a76, a77, a79, a81, a83, a86, a88, a92, a93, a95, a96, a98, a99, a103, a108, a111, a114, a115, a116, a117, a125, a129, a130, a135, a139, a140, a141, a142, a143, a144, a145, a146, a147, a148.',
#        'c1 :- a0, a2, a3, a5, a6, a8, a9, a11, a12, a13, a14, a15, a16, a18, a19, a21, a24, a25, a26, a27, a30, a34, a36, a38, a39, a43, a45, a47, a48, a49, a52, a54, a56, a61, a63, a64, a68, a71, a73, a74, a76, a77, a78, a79, a82, a86, a88, a92, a94, a98, a100, a103, a104, a107, a108, a110, a111, a115, a117, a118, a122, a124, a125, a126, a127, a129, a130, a132, a133, a135, a137, a138, a139, a140, a141, a143, a145, a146, a148.',
#        'c2 :- a0, a2, a4, a5, a6, a7, a8, a9, a11, a12, a13, a14, a15, a17, a19, a20, a21, a23, a26, a29, a30, a36, a37, a39, a42, a43, a45, a46, a47, a48, a54, a55, a57, a59, a60, a61, a66, a67, a72, a74, a77, a79, a80, a84, a89, a92, a93, a94, a95, a97, a98, a100, a102, a103, a104, a106, a107, a111, a112, a113, a114, a115, a116, a119, a120, a122, a125, a131, a132, a134, a136, a138, a140, a145, a149.',
#        'c3 :- a2, a3, a4, a7, a8, a12, a13, a14, a15, a16, a17, a18, a19, a21, a26, a28, a29, a33, a35, a37, a38, a39, a41, a46, a48, a51, a54, a55, a60, a65, a67, a68, a70, a73, a75, a76, a78, a79, a81, a84, a85, a88, a89, a91, a95, a97, a103, a104, a105, a106, a107, a110, a111, a112, a116, a120, a121, a122, a124, a127, a129, a130, a131, a138, a140, a141, a144, a146, a147, a148.',
#        'c4 :- a0, a1, a2, a4, a8, a9, a10, a16, a19, a23, a32, a37, a38, a39, a41, a42, a48, a49, a50, a54, a55, a56, a63, a64, a65, a71, a74, a76, a80, a81, a82, a83, a85, a86, a88, a96, a99, a102, a104, a105, a108, a111, a112, a113, a117, a118, a120, a123, a124, a128, a130, a132, a133, a135, a136, a140, a141, a142, a143, a144, a146, a147.',
#        'c5 :- a0, a1, a2, a3, a4, a5, a8, a10, a16, a20, a21, a23, a24, a27, a29, a30, a31, a32, a35, a37, a38, a41, a42, a43, a46, a47, a50, a53, a55, a56, a57, a59, a65, a66, a67, a68, a69, a70, a73, a74, a77, a80, a82, a83, a84, a86, a87, a89, a97, a99, a100, a101, a103, a104, a105, a107, a108, a110, a113, a114, a115, a118, a119, a120, a121, a123, a124, a129, a130, a135, a137, a140, a144, a145, a147, a148, a149.',
#        'c6 :- a0, a1, a2, a3, a4, a5, a7, a8, a11, a13, a17, a18, a20, a24, a27, a30, a31, a35, a37, a38, a40, a41, a43, a44, a46, a47, a50, a51, a52, a54, a55, a56, a57, a58, a61, a64, a65, a66, a68, a69, a74, a75, a76, a77, a79, a80, a81, a83, a89, a90, a91, a93, a94, a95, a98, a100, a102, a104, a106, a110, a113, a114, a115, a116, a117, a118, a119, a125, a127, a130, a132, a135, a139, a140, a141, a142, a143, a144, a145, a146, a147, a149.',
#        'c7 :- a0, a3, a4, a7, a8, a9, a13, a14, a15, a16, a18, a19, a20, a21, a24, a25, a26, a27, a28, a29, a31, a32, a36, a37, a40, a41, a42, a43, a49, a50, a57, a58, a59, a60, a62, a67, a69, a71, a72, a73, a76, a81, a82, a83, a85, a88, a90, a92, a94, a95, a97, a99, a101, a102, a103, a104, a111, a114, a117, a119, a121, a123, a124, a126, a129, a131, a132, a135, a138, a139, a140, a141, a142, a143, a144, a149.',
#        'c8 :- a0, a1, a2, a6, a8, a9, a10, a11, a13, a16, a19, a20, a21, a23, a25, a27, a29, a33, a34, a36, a37, a43, a45, a46, a51, a52, a53, a54, a56, a57, a58, a62, a64, a65, a67, a70, a71, a73, a74, a75, a78, a80, a81, a83, a84, a85, a86, a87, a88, a91, a92, a93, a95, a96, a98, a99, a100, a101, a102, a104, a106, a107, a113, a124, a126, a128, a130, a131, a132, a133, a134, a136, a137, a138, a140, a141, a145, a148, a149.',
#        'c9 :- a0, a2, a3, a7, a8, a9, a11, a15, a16, a17, a18, a22, a23, a26, a28, a37, a41, a42, a48, a49, a51, a53, a57, a62, a63, a66, a68, a71, a73, a74, a75, a76, a78, a79, a80, a81, a82, a83, a86, a87, a88, a90, a91, a92, a93, a99, a100, a104, a106, a107, a109, a110, a113, a115, a117, a118, a119, a120, a121, a122, a124, a126, a128, a129, a132, a133, a135, a136, a139, a140, a144, a146, a147, a149.',
#        'c10 :- a0, a1, a2, a3, a5, a9, a11, a12, a13, a15, a17, a18, a20, a22, a24, a25, a26, a29, a30, a34, a36, a37, a41, a42, a45, a53, a54, a56, a57, a59, a61, a65, a70, a72, a75, a78, a80, a81, a83, a91, a93, a94, a95, a104, a106, a108, a109, a111, a117, a119, a120, a123, a124, a125, a126, a127, a128, a131, a134, a135, a140, a141, a142, a143.',
#        'c11 :- a2, a3, a4, a5, a6, a8, a9, a10, a12, a14, a15, a16, a17, a18, a19, a26, a27, a31, a32, a34, a37, a38, a43, a44, a46, a47, a48, a49, a50, a51, a53, a56, a57, a58, a60, a61, a62, a64, a67, a68, a69, a72, a73, a75, a76, a81, a86, a88, a89, a91, a95, a97, a99, a101, a103, a104, a106, a108, a109, a113, a122, a123, a124, a125, a127, a128, a129, a130, a131, a133, a135, a136, a137, a138, a139, a141, a142, a144, a145, a147.',
#        'c12 :- a0, a3, a4, a8, a9, a11, a12, a13, a16, a17, a18, a19, a20, a24, a25, a28, a29, a30, a32, a33, a34, a37, a38, a39, a40, a43, a46, a47, a48, a49, a50, a54, a55, a56, a57, a61, a62, a63, a64, a66, a67, a69, a70, a73, a74, a76, a77, a79, a83, a84, a87, a90, a92, a95, a100, a101, a104, a105, a106, a109, a112, a113, a114, a116, a117, a122, a125, a127, a130, a131, a133, a135, a137, a138, a141, a143, a144, a145, a146, a148.',
#        'c13 :- a2, a3, a6, a8, a9, a11, a15, a16, a17, a19, a21, a24, a27, a28, a30, a33, a35, a38, a40, a41, a42, a43, a45, a47, a48, a49, a51, a52, a53, a57, a58, a60, a62, a64, a67, a69, a70, a72, a75, a77, a78, a81, a83, a84, a85, a87, a93, a95, a97, a99, a100, a104, a105, a106, a116, a118, a119, a120, a121, a122, a124, a128, a129, a131, a133, a134, a135, a141, a145, a148, a149.',
#        'c14 :- a0, a1, a3, a4, a10, a11, a13, a15, a16, a18, a19, a20, a21, a22, a23, a27, a38, a39, a40, a45, a47, a48, a49, a51, a54, a55, a56, a58, a59, a61, a62, a67, a70, a71, a72, a73, a75, a77, a78, a82, a83, a87, a88, a89, a90, a92, a94, a97, a98, a100, a101, a106, a108, a110, a111, a112, a113, a114, a116, a117, a119, a120, a121, a122, a123, a124, a126, a128, a129, a130, a131, a132, a137, a138, a139, a140, a141, a142, a143, a146, a148.',
#        'c15 :- a3, a6, a8, a14, a21, a24, a26, a28, a29, a32, a34, a35, a37, a39, a43, a44, a46, a47, a52, a53, a56, a57, a58, a60, a61, a62, a63, a64, a66, a67, a70, a71, a77, a78, a80, a81, a82, a85, a86, a90, a91, a92, a94, a95, a97, a101, a103, a104, a105, a109, a111, a112, a113, a115, a116, a118, a119, a120, a121, a125, a126, a127, a128, a130, a132, a133, a134, a135, a136, a137, a139, a142, a143, a145, a149.',
#        'c16 :- a0, a2, a4, a5, a6, a7, a9, a12, a13, a16, a21, a23, a24, a25, a26, a27, a33, a34, a35, a36, a40, a41, a43, a46, a48, a50, a55, a57, a59, a60, a62, a63, a66, a67, a68, a73, a74, a76, a77, a80, a84, a85, a91, a94, a95, a96, a97, a98, a104, a105, a107, a109, a111, a113, a116, a119, a121, a122, a124, a125, a127, a128, a129, a133, a134, a136, a138, a139, a140, a142, a144, a145, a146, a148.',
#        'c17 :- a3, a8, a9, a12, a13, a14, a15, a16, a18, a19, a22, a25, a26, a27, a28, a30, a31, a32, a35, a36, a37, a38, a39, a40, a41, a44, a46, a47, a49, a52, a54, a55, a58, a59, a60, a62, a63, a68, a72, a73, a74, a80, a82, a85, a86, a87, a90, a94, a97, a99, a103, a104, a105, a107, a109, a111, a114, a115, a119, a120, a122, a124, a125, a128, a129, a134, a136, a139, a140, a143, a144, a146, a148.',
#        'c18 :- a1, a2, a3, a4, a5, a11, a14, a19, a20, a22, a25, a27, a28, a31, a33, a34, a36, a40, a41, a43, a44, a45, a46, a47, a49, a53, a55, a58, a59, a63, a64, a66, a68, a72, a73, a79, a83, a84, a87, a88, a92, a93, a95, a97, a100, a104, a105, a106, a107, a109, a111, a115, a118, a119, a120, a121, a122, a124, a125, a126, a128, a131, a132, a134, a136, a137, a138, a140, a142, a144, a145, a146, a149.',
#        'c19 :- a0, a7, a8, a10, a12, a14, a15, a16, a17, a19, a20, a21, a22, a23, a26, a30, a31, a34, a35, a45, a47, a48, a52, a54, a57, a59, a61, a64, a67, a68, a69, a71, a73, a74, a75, a76, a77, a78, a79, a82, a83, a86, a91, a92, a94, a96, a97, a98, a99, a100, a104, a106, a107, a108, a109, a113, a115, a117, a118, a122, a124, a125, a126, a127, a128, a129, a130, a132, a134, a138, a139, a140, a142, a147, a148.',
#        'c20 :- a0, a1, a3, a4, a5, a6, a8, a9, a10, a13, a14, a18, a19, a20, a22, a27, a28, a31, a37, a38, a39, a41, a42, a44, a46, a47, a48, a49, a51, a53, a55, a56, a61, a63, a64, a66, a70, a72, a76, a77, a79, a81, a82, a84, a86, a87, a88, a91, a94, a95, a96, a98, a100, a102, a103, a106, a112, a113, a118, a120, a123, a124, a125, a129, a130, a131, a135, a136, a137, a138, a141, a143, a144.',
#        'c21 :- a3, a5, a8, a9, a10, a14, a16, a17, a18, a19, a22, a23, a27, a31, a36, a38, a40, a44, a45, a51, a52, a55, a60, a62, a65, a66, a69, a70, a79, a83, a85, a86, a87, a92, a93, a99, a101, a102, a103, a106, a109, a111, a113, a116, a119, a121, a124, a126, a131, a132, a134, a135, a139, a140, a141, a144, a145, a146, a147.',
#        'c22 :- a7, a9, a11, a16, a17, a18, a20, a21, a23, a24, a25, a26, a27, a31, a32, a33, a36, a38, a40, a41, a42, a43, a47, a48, a51, a52, a53, a56, a57, a58, a64, a65, a67, a68, a69, a70, a71, a73, a75, a76, a77, a78, a79, a81, a82, a85, a87, a89, a90, a92, a94, a110, a111, a112, a113, a114, a116, a118, a119, a120, a121, a122, a123, a124, a126, a127, a128, a129, a130, a131, a133, a134, a135, a136, a137, a138, a139, a143, a145, a146, a147.',
#        'c23 :- a0, a2, a4, a5, a7, a10, a11, a14, a16, a19, a20, a23, a29, a30, a31, a32, a33, a35, a38, a39, a41, a42, a45, a47, a48, a56, a57, a58, a59, a60, a61, a62, a63, a65, a67, a68, a75, a77, a78, a79, a80, a84, a86, a90, a94, a95, a96, a97, a99, a102, a103, a105, a107, a108, a112, a113, a119, a121, a126, a127, a128, a130, a131, a132, a133, a135, a136, a138, a143, a144, a148, a149.',
#        'c24 :- a1, a3, a4, a6, a7, a15, a16, a19, a20, a21, a24, a25, a26, a27, a36, a39, a46, a49, a51, a53, a54, a62, a63, a66, a72, a79, a82, a84, a86, a92, a93, a94, a96, a97, a98, a102, a103, a104, a105, a106, a110, a114, a116, a119, a120, a121, a122, a123, a125, a126, a128, a130, a134, a135, a136, a140, a142, a147.',
#        'c25 :- a0, a1, a2, a3, a4, a7, a8, a12, a13, a14, a15, a16, a19, a22, a23, a24, a26, a28, a31, a32, a33, a37, a38, a41, a42, a45, a46, a47, a48, a49, a52, a54, a55, a56, a57, a58, a59, a62, a68, a71, a72, a73, a78, a79, a82, a83, a84, a85, a89, a90, a92, a94, a98, a99, a101, a104, a112, a113, a116, a119, a120, a121, a123, a127, a128, a129, a130, a138, a142, a144, a146, a147, a149.',
#        'c26 :- a0, a4, a5, a6, a10, a12, a13, a14, a15, a17, a20, a21, a22, a23, a24, a26, a27, a28, a30, a33, a34, a35, a36, a41, a45, a48, a50, a51, a53, a58, a59, a60, a61, a64, a66, a70, a71, a76, a78, a79, a81, a83, a85, a86, a87, a88, a90, a91, a92, a93, a95, a96, a101, a102, a103, a105, a107, a111, a112, a113, a118, a123, a125, a129, a133, a136, a137, a138, a140, a143, a144, a145, a147.',
#        'c27 :- a2, a3, a4, a6, a10, a11, a12, a17, a18, a19, a21, a22, a26, a28, a29, a33, a34, a37, a38, a39, a43, a45, a46, a47, a48, a49, a51, a52, a53, a56, a57, a59, a65, a66, a67, a68, a69, a71, a73, a74, a78, a79, a80, a82, a83, a89, a91, a92, a99, a100, a101, a103, a106, a107, a108, a110, a111, a112, a113, a116, a118, a119, a120, a121, a122, a123, a124, a125, a130, a134, a135, a136, a137, a139, a142, a143, a144, a146, a148.',
#        'c28 :- a0, a1, a2, a5, a8, a10, a12, a15, a16, a17, a19, a20, a22, a26, a28, a29, a34, a35, a40, a41, a43, a44, a50, a51, a52, a54, a55, a56, a57, a59, a63, a64, a66, a67, a72, a73, a75, a76, a77, a78, a79, a82, a84, a85, a87, a89, a91, a94, a95, a96, a98, a100, a101, a106, a108, a109, a112, a113, a114, a116, a117, a118, a120, a122, a123, a125, a127, a128, a129, a133, a137, a141, a144, a145, a147.',
#        'c29 :- a3, a4, a7, a11, a12, a13, a16, a17, a18, a19, a22, a24, a28, a29, a30, a31, a32, a33, a34, a35, a38, a39, a41, a43, a44, a45, a47, a50, a55, a56, a58, a59, a60, a64, a67, a69, a70, a72, a74, a76, a78, a79, a83, a84, a85, a86, a87, a88, a90, a91, a92, a93, a94, a95, a96, a97, a104, a106, a107, a109, a113, a115, a116, a117, a118, a119, a121, a122, a124, a127, a128, a129, a131, a133, a136, a138, a139, a140, a144, a147, a149.',
#        'c30 :- a0, a1, a2, a4, a5, a8, a10, a12, a13, a17, a19, a25, a29, a30, a32, a34, a35, a36, a37, a40, a41, a42, a43, a44, a46, a49, a51, a58, a59, a62, a64, a66, a71, a73, a74, a75, a76, a77, a80, a82, a85, a86, a87, a88, a89, a90, a92, a94, a98, a99, a103, a104, a105, a106, a108, a109, a110, a111, a112, a113, a116, a118, a121, a122, a123, a125, a126, a130, a134, a136, a139, a145, a146, a148.',
#        'c31 :- a0, a1, a3, a5, a6, a9, a12, a14, a16, a18, a19, a22, a24, a25, a26, a27, a31, a32, a33, a34, a35, a36, a38, a40, a42, a43, a48, a49, a51, a52, a53, a56, a57, a61, a62, a63, a66, a71, a74, a75, a77, a78, a79, a80, a83, a84, a85, a86, a89, a90, a91, a92, a95, a96, a98, a99, a108, a113, a114, a115, a117, a120, a121, a122, a124, a125, a126, a127, a128, a129, a130, a132, a133, a135, a139, a142, a145, a146, a148.',
#        'c32 :- a1, a3, a4, a5, a10, a11, a12, a14, a16, a18, a19, a23, a26, a27, a28, a29, a30, a32, a33, a36, a41, a42, a43, a45, a48, a49, a51, a53, a54, a56, a57, a60, a61, a63, a65, a66, a68, a69, a72, a76, a77, a83, a85, a88, a89, a90, a94, a95, a96, a98, a99, a101, a104, a105, a113, a114, a115, a117, a118, a119, a120, a122, a126, a129, a131, a133, a135, a136, a137, a142, a144, a148, a149.',
#        'c33 :- a1, a2, a3, a4, a5, a7, a10, a11, a15, a19, a20, a21, a23, a24, a27, a28, a32, a33, a37, a38, a39, a40, a41, a44, a45, a50, a51, a52, a53, a55, a56, a57, a59, a61, a63, a65, a66, a70, a71, a72, a73, a74, a76, a77, a80, a81, a84, a85, a86, a87, a90, a91, a94, a95, a96, a98, a102, a103, a104, a106, a107, a109, a112, a114, a116, a117, a120, a122, a123, a125, a127, a128, a129, a131, a132, a133, a134, a136, a137, a139, a140, a141, a142, a143, a145, a146, a147, a148, a149.',
#        'c34 :- a0, a2, a5, a7, a10, a11, a13, a15, a18, a21, a27, a29, a31, a32, a33, a36, a39, a41, a42, a43, a44, a45, a46, a48, a52, a61, a62, a66, a75, a76, a78, a82, a83, a85, a86, a88, a89, a90, a93, a95, a97, a100, a106, a108, a109, a113, a114, a115, a116, a120, a121, a122, a124, a125, a126, a128, a129, a130, a131, a133, a134, a136, a142, a144, a146, a147.',
#        'c35 :- a8, a11, a13, a15, a18, a23, a26, a27, a28, a29, a33, a36, a39, a40, a43, a44, a47, a48, a49, a51, a52, a56, a57, a58, a59, a61, a65, a66, a69, a70, a71, a75, a78, a81, a82, a83, a85, a86, a87, a89, a90, a92, a93, a94, a97, a99, a100, a101, a104, a106, a107, a108, a110, a112, a115, a116, a122, a123, a124, a125, a127, a129, a130, a131, a132, a133, a134, a138, a140, a141, a142, a144, a145, a146, a147, a148.',
#        'c36 :- a0, a1, a2, a3, a5, a6, a7, a8, a17, a20, a21, a22, a24, a27, a28, a29, a30, a31, a32, a34, a36, a37, a39, a40, a41, a42, a43, a44, a45, a47, a50, a51, a52, a53, a54, a59, a60, a62, a63, a64, a65, a67, a68, a69, a70, a72, a75, a76, a77, a79, a81, a82, a89, a90, a91, a92, a96, a97, a100, a101, a102, a103, a104, a109, a111, a113, a115, a116, a119, a120, a121, a123, a124, a133, a134, a136, a137, a141, a143, a147.',
#        'c37 :- a0, a3, a5, a8, a9, a10, a11, a18, a20, a21, a22, a23, a25, a26, a27, a30, a32, a34, a35, a36, a37, a38, a40, a45, a47, a49, a52, a53, a58, a62, a63, a73, a77, a78, a85, a86, a89, a90, a93, a94, a96, a102, a103, a105, a107, a109, a112, a115, a117, a129, a130, a131, a132, a134, a135, a137, a139, a140, a144, a147, a148, a149.',
#        'c38 :- a0, a1, a2, a3, a4, a5, a10, a12, a14, a16, a19, a21, a22, a23, a24, a26, a27, a28, a29, a32, a33, a34, a37, a38, a43, a46, a47, a49, a59, a62, a63, a66, a70, a73, a74, a75, a76, a77, a79, a81, a85, a87, a89, a91, a93, a94, a96, a102, a103, a106, a108, a111, a112, a113, a115, a116, a117, a119, a125, a127, a128, a130, a131, a132, a136, a137, a142, a143, a144, a145, a146, a147, a148.',
#        'c39 :- a1, a3, a5, a7, a8, a10, a11, a14, a15, a17, a18, a20, a24, a26, a32, a34, a35, a36, a37, a39, a42, a43, a44, a45, a47, a48, a51, a52, a53, a55, a57, a59, a62, a63, a64, a65, a69, a70, a74, a75, a76, a77, a81, a82, a84, a90, a91, a93, a96, a97, a98, a100, a102, a107, a109, a113, a116, a118, a119, a120, a121, a122, a123, a124, a126, a128, a129, a130, a135, a136, a138, a139, a140, a145, a147, a149.',
#        'c40 :- a3, a5, a8, a9, a11, a12, a14, a17, a18, a25, a26, a28, a29, a30, a38, a39, a40, a42, a44, a45, a49, a50, a52, a53, a55, a58, a61, a63, a65, a67, a69, a70, a71, a72, a75, a78, a80, a81, a82, a84, a85, a87, a88, a90, a91, a92, a93, a97, a98, a99, a100, a101, a104, a107, a109, a110, a113, a114, a116, a118, a119, a120, a122, a123, a125, a126, a129, a131, a133, a134, a135, a136, a138, a140, a141, a144, a145, a146, a147, a149.',
#        'c41 :- a5, a7, a10, a11, a14, a15, a19, a20, a21, a23, a27, a28, a31, a32, a35, a36, a37, a40, a42, a43, a44, a45, a47, a51, a52, a53, a57, a60, a61, a64, a65, a66, a67, a72, a73, a74, a76, a78, a81, a82, a85, a86, a89, a92, a93, a95, a98, a99, a101, a103, a104, a106, a107, a108, a113, a114, a115, a116, a117, a118, a122, a124, a127, a130, a131, a133, a134, a135, a137, a138, a140, a141, a142, a143.',
#        'c42 :- a3, a4, a8, a9, a10, a11, a12, a13, a14, a20, a21, a24, a25, a27, a28, a29, a30, a32, a33, a37, a38, a40, a42, a47, a49, a50, a52, a53, a54, a57, a59, a60, a62, a63, a65, a66, a69, a70, a71, a72, a73, a75, a76, a77, a78, a80, a82, a83, a85, a86, a89, a90, a92, a93, a95, a98, a101, a102, a105, a106, a109, a111, a112, a113, a115, a116, a118, a119, a120, a121, a125, a127, a128, a129, a130, a131, a132, a133, a134, a139, a142, a143, a144, a145, a146, a147, a148, a149.',
#        'c43 :- a0, a1, a3, a9, a10, a14, a19, a22, a23, a25, a27, a28, a31, a32, a33, a34, a35, a36, a41, a43, a44, a46, a48, a49, a50, a51, a52, a58, a59, a60, a63, a65, a66, a68, a69, a70, a72, a73, a74, a75, a79, a81, a82, a83, a85, a86, a94, a95, a99, a101, a103, a105, a106, a107, a113, a114, a116, a117, a120, a123, a125, a126, a127, a130, a131, a134, a136, a137, a139, a140, a141, a142, a143, a145, a146, a149.',
#        'c44 :- a0, a7, a10, a16, a17, a19, a22, a23, a24, a25, a27, a28, a30, a35, a36, a37, a38, a44, a45, a46, a47, a48, a51, a52, a53, a54, a55, a56, a58, a59, a64, a65, a66, a68, a69, a70, a74, a75, a77, a78, a79, a80, a82, a83, a84, a85, a86, a88, a89, a90, a91, a93, a96, a97, a99, a100, a102, a103, a105, a109, a110, a115, a116, a117, a121, a124, a125, a127, a128, a130, a131, a132, a133, a137, a138, a139, a140, a141, a142, a143, a144, a145, a147, a148.',
#        'c45 :- a0, a2, a3, a6, a7, a10, a11, a13, a14, a15, a16, a17, a20, a21, a24, a27, a29, a33, a34, a35, a36, a37, a38, a40, a42, a43, a47, a49, a50, a51, a52, a54, a55, a56, a57, a58, a59, a60, a63, a64, a65, a67, a68, a70, a74, a75, a76, a77, a78, a79, a81, a82, a84, a85, a87, a90, a91, a92, a96, a97, a99, a100, a101, a102, a103, a106, a108, a109, a111, a113, a117, a120, a122, a123, a125, a126, a130, a131, a133, a134, a137, a138, a139, a140, a144, a145, a147.',
#        'c46 :- a0, a2, a4, a7, a8, a13, a15, a16, a19, a20, a22, a23, a24, a26, a27, a29, a33, a35, a36, a37, a38, a39, a42, a46, a48, a50, a56, a58, a60, a61, a62, a64, a65, a66, a67, a68, a71, a73, a74, a75, a76, a77, a79, a80, a81, a82, a84, a85, a87, a88, a92, a93, a96, a97, a100, a102, a105, a106, a107, a109, a113, a114, a115, a116, a117, a118, a119, a120, a123, a128, a131, a132, a134, a137, a141, a142, a145, a148, a149.',
#        'c47 :- a1, a2, a3, a4, a5, a7, a9, a10, a14, a15, a17, a18, a19, a20, a22, a23, a25, a26, a27, a33, a34, a41, a42, a44, a45, a46, a50, a52, a57, a58, a63, a64, a65, a66, a67, a68, a70, a72, a74, a77, a78, a80, a83, a86, a88, a90, a91, a92, a93, a94, a96, a100, a103, a104, a105, a106, a107, a108, a111, a113, a115, a117, a119, a122, a123, a125, a130, a131, a133, a135, a136, a138, a142, a145, a148, a149.',
#        'c48 :- a0, a5, a6, a9, a12, a13, a15, a22, a23, a24, a27, a29, a30, a33, a34, a36, a37, a44, a45, a46, a49, a50, a51, a54, a55, a57, a58, a59, a60, a61, a62, a70, a71, a72, a78, a79, a81, a86, a87, a88, a92, a93, a94, a96, a99, a101, a102, a103, a106, a107, a108, a113, a115, a116, a120, a121, a123, a125, a126, a129, a131, a144, a146, a147.',
#        'c49 :- a4, a5, a7, a11, a13, a15, a19, a26, a30, a31, a33, a34, a35, a36, a39, a40, a41, a42, a44, a51, a52, a54, a55, a57, a58, a59, a60, a62, a65, a70, a71, a72, a76, a77, a80, a81, a82, a83, a88, a89, a91, a93, a94, a96, a97, a98, a100, a101, a103, a105, a106, a108, a110, a111, a112, a114, a115, a116, a118, a119, a120, a121, a130, a131, a132, a134, a135, a136, a137, a139, a141, a143, a144, a147, a149.',
#        'c50 :- a1, a3, a5, a6, a7, a8, a12, a14, a18, a20, a23, a27, a28, a29, a31, a32, a34, a37, a38, a40, a41, a42, a45, a48, a49, a50, a53, a54, a55, a56, a57, a58, a59, a60, a61, a63, a64, a66, a67, a68, a69, a70, a74, a75, a76, a78, a82, a83, a89, a90, a93, a95, a96, a97, a98, a99, a100, a104, a105, a107, a108, a109, a112, a115, a120, a121, a123, a124, a125, a126, a127, a129, a131, a135, a136, a138, a139, a145, a146, a148.',
#        'c51 :- a1, a2, a3, a5, a6, a7, a9, a11, a13, a14, a17, a18, a19, a22, a27, a28, a29, a34, a36, a41, a42, a44, a45, a47, a51, a52, a54, a56, a59, a60, a62, a64, a69, a71, a72, a74, a78, a83, a85, a86, a87, a88, a89, a93, a94, a97, a98, a104, a108, a112, a117, a120, a123, a124, a125, a126, a129, a133, a134, a135, a136, a138, a139, a141, a142, a144, a145, a148, a149.',
#        'c52 :- a0, a2, a3, a7, a12, a15, a16, a17, a18, a19, a25, a26, a28, a30, a32, a34, a37, a38, a39, a45, a48, a50, a51, a54, a58, a59, a64, a66, a67, a68, a69, a70, a71, a72, a74, a81, a83, a84, a85, a88, a89, a91, a92, a98, a100, a102, a105, a106, a107, a111, a112, a114, a115, a118, a120, a122, a129, a130, a131, a132, a133, a135, a136, a137, a138, a140, a142, a143, a145, a146, a147.',
#        'c53 :- a2, a5, a6, a7, a8, a9, a14, a15, a16, a17, a23, a24, a32, a34, a36, a38, a39, a44, a46, a47, a48, a49, a50, a51, a56, a57, a63, a64, a65, a67, a68, a73, a75, a76, a77, a82, a84, a85, a86, a88, a89, a91, a97, a99, a100, a102, a105, a106, a107, a108, a109, a111, a113, a116, a118, a119, a124, a125, a126, a129, a131, a132, a133, a134, a135, a136, a139, a141, a143, a144, a145, a146, a147.',
#        'c54 :- a1, a2, a3, a7, a10, a11, a13, a14, a16, a17, a19, a22, a27, a28, a29, a31, a34, a35, a39, a43, a44, a45, a47, a49, a50, a51, a52, a53, a54, a55, a57, a58, a61, a62, a64, a68, a73, a74, a75, a81, a84, a91, a93, a94, a100, a102, a103, a104, a106, a109, a111, a114, a118, a120, a121, a127, a128, a129, a132, a133, a134, a135, a136, a139, a141, a143, a145, a146, a147, a148, a149.',
#        'c55 :- a4, a6, a10, a13, a15, a16, a17, a20, a21, a25, a27, a28, a29, a31, a33, a34, a35, a36, a38, a39, a40, a41, a43, a44, a45, a47, a49, a50, a54, a55, a58, a59, a60, a66, a71, a72, a73, a74, a76, a78, a80, a82, a84, a85, a86, a87, a89, a90, a92, a94, a95, a97, a98, a100, a102, a105, a106, a107, a108, a109, a111, a112, a114, a115, a116, a117, a118, a119, a120, a121, a122, a128, a129, a132, a133, a138, a140, a141, a144, a148.',
#        'c56 :- a0, a1, a2, a4, a5, a7, a8, a9, a12, a16, a21, a24, a25, a27, a28, a29, a32, a33, a36, a37, a38, a41, a42, a44, a47, a48, a49, a50, a51, a52, a53, a55, a56, a62, a65, a68, a69, a71, a76, a77, a83, a84, a87, a94, a95, a98, a101, a102, a108, a109, a110, a111, a112, a115, a117, a119, a120, a121, a126, a127, a134, a136, a139, a140, a142, a143, a145, a146, a147, a148, a149.',
#        'c57 :- a0, a2, a3, a4, a6, a10, a13, a16, a19, a20, a21, a22, a23, a26, a27, a29, a30, a32, a35, a36, a37, a38, a40, a44, a45, a46, a49, a52, a53, a58, a61, a62, a63, a65, a66, a67, a69, a70, a71, a72, a73, a74, a75, a76, a77, a79, a82, a84, a87, a88, a92, a94, a95, a98, a100, a101, a102, a103, a105, a106, a107, a110, a111, a113, a115, a116, a121, a123, a124, a126, a128, a129, a131, a135, a137, a138, a140, a141, a142, a143, a147, a148, a149.',
#        'c58 :- a2, a3, a6, a7, a9, a10, a12, a14, a16, a17, a18, a20, a21, a22, a23, a24, a27, a29, a30, a31, a32, a33, a34, a35, a37, a38, a39, a40, a42, a43, a44, a45, a47, a49, a52, a53, a54, a58, a60, a64, a65, a66, a67, a69, a72, a73, a75, a76, a77, a82, a84, a85, a88, a90, a91, a92, a95, a96, a97, a98, a100, a101, a102, a104, a105, a106, a111, a112, a116, a117, a118, a119, a120, a122, a124, a127, a128, a134, a136, a140, a143, a145, a148, a149.',
#        'c59 :- a3, a6, a7, a9, a10, a13, a17, a18, a19, a25, a27, a28, a35, a39, a40, a41, a43, a50, a51, a52, a53, a54, a56, a61, a62, a64, a65, a67, a68, a70, a72, a76, a81, a84, a85, a88, a89, a91, a94, a95, a96, a101, a102, a104, a106, a111, a112, a113, a114, a118, a119, a121, a123, a127, a128, a130, a132, a134, a138, a139, a140, a141, a142, a146, a147, a148, a149.',
#        'c60 :- a0, a5, a11, a12, a15, a16, a17, a18, a22, a23, a24, a25, a26, a28, a29, a31, a33, a35, a36, a37, a38, a40, a42, a43, a44, a45, a49, a52, a53, a56, a59, a64, a67, a68, a69, a70, a71, a76, a78, a81, a87, a89, a91, a93, a94, a95, a96, a97, a98, a99, a100, a101, a102, a106, a110, a111, a115, a116, a118, a119, a121, a123, a124, a125, a127, a128, a129, a131, a133, a134, a140, a141, a143, a145, a148, a149.',
#        'c61 :- a1, a2, a3, a4, a7, a9, a10, a12, a13, a16, a18, a23, a26, a27, a31, a32, a35, a36, a39, a40, a41, a44, a45, a46, a52, a53, a56, a57, a59, a60, a61, a62, a63, a64, a65, a71, a78, a79, a80, a82, a84, a85, a86, a89, a90, a91, a92, a98, a99, a101, a104, a106, a107, a109, a110, a111, a112, a113, a115, a118, a119, a120, a122, a123, a126, a128, a129, a131, a133, a135, a137, a139, a142, a143, a144, a145, a146, a147, a148.',
#        'c62 :- a2, a3, a7, a8, a9, a10, a13, a15, a17, a20, a26, a35, a37, a40, a41, a42, a43, a44, a45, a48, a51, a52, a53, a55, a57, a59, a61, a62, a63, a65, a71, a72, a73, a74, a75, a77, a83, a86, a87, a91, a93, a96, a99, a100, a101, a107, a113, a114, a116, a117, a125, a127, a129, a131, a132, a135, a136, a138, a140, a141, a142, a143, a145, a146, a147.',
#        'c63 :- a3, a6, a10, a15, a17, a18, a19, a23, a24, a26, a27, a30, a32, a33, a34, a35, a37, a38, a39, a41, a43, a46, a47, a49, a54, a56, a59, a60, a65, a66, a69, a70, a71, a74, a76, a77, a78, a79, a84, a85, a89, a91, a92, a94, a97, a99, a100, a101, a102, a104, a105, a106, a107, a108, a112, a113, a115, a116, a120, a121, a123, a125, a127, a129, a130, a131, a132, a133, a134, a137, a138, a140, a143, a144, a146, a147.',
#        'c64 :- a0, a5, a8, a12, a14, a16, a19, a22, a24, a25, a27, a28, a34, a35, a37, a39, a40, a45, a48, a50, a51, a52, a54, a55, a57, a58, a60, a61, a65, a67, a69, a70, a71, a72, a75, a76, a77, a78, a79, a84, a88, a92, a94, a96, a97, a103, a104, a105, a108, a110, a112, a117, a118, a119, a120, a125, a126, a127, a128, a129, a130, a133, a135, a138, a139, a140, a145, a147, a149.',
#        'c65 :- a0, a1, a5, a10, a11, a12, a14, a17, a18, a20, a22, a23, a24, a26, a28, a29, a31, a32, a36, a37, a39, a40, a41, a43, a48, a50, a51, a53, a55, a56, a60, a64, a66, a70, a71, a73, a74, a76, a77, a79, a82, a83, a85, a86, a87, a93, a95, a96, a97, a99, a100, a102, a103, a106, a108, a109, a110, a111, a116, a117, a118, a119, a123, a125, a126, a128, a129, a130, a132, a134, a135, a138, a139, a141, a142, a144.',
#        'c66 :- a0, a2, a3, a6, a7, a10, a11, a13, a14, a15, a16, a17, a19, a21, a23, a24, a25, a26, a31, a34, a39, a41, a42, a48, a54, a58, a61, a66, a67, a70, a71, a73, a75, a76, a77, a79, a80, a81, a82, a83, a84, a85, a86, a92, a93, a95, a96, a97, a102, a104, a105, a107, a108, a111, a112, a113, a114, a115, a116, a119, a120, a122, a124, a125, a126, a127, a128, a130, a135, a137, a138, a139, a141.',
#        'c67 :- a1, a2, a5, a6, a8, a11, a13, a15, a17, a18, a19, a21, a22, a23, a27, a28, a31, a32, a33, a34, a39, a42, a44, a45, a46, a50, a52, a53, a57, a58, a59, a60, a61, a62, a63, a64, a66, a68, a69, a73, a74, a76, a77, a82, a83, a84, a87, a89, a91, a96, a97, a99, a100, a101, a103, a104, a108, a109, a111, a112, a114, a116, a117, a121, a122, a123, a124, a126, a127, a128, a129, a130, a133, a134, a137, a140, a143, a145, a146, a148, a149.',
#        'c68 :- a0, a2, a3, a4, a5, a6, a8, a9, a10, a13, a14, a15, a17, a18, a20, a21, a23, a26, a27, a29, a30, a32, a33, a34, a35, a36, a38, a40, a43, a44, a45, a47, a48, a49, a50, a51, a52, a55, a59, a63, a64, a66, a67, a69, a70, a73, a74, a75, a79, a80, a81, a83, a84, a88, a89, a91, a93, a96, a99, a102, a105, a107, a109, a111, a112, a114, a116, a117, a120, a121, a123, a124, a126, a137, a138, a139, a140, a141, a145, a146.',
#        'c69 :- a0, a3, a4, a7, a8, a10, a12, a15, a17, a19, a21, a23, a26, a27, a28, a29, a35, a36, a37, a38, a40, a41, a43, a45, a46, a47, a49, a51, a52, a53, a59, a63, a65, a66, a67, a68, a70, a79, a80, a82, a83, a93, a94, a95, a96, a97, a98, a99, a101, a102, a103, a109, a110, a111, a112, a114, a115, a120, a121, a123, a127, a128, a129, a132, a133, a135, a142, a144, a145, a147, a148, a149.',
#        'c70 :- a1, a2, a4, a5, a6, a8, a9, a10, a13, a15, a17, a18, a19, a29, a32, a33, a35, a36, a43, a44, a45, a46, a47, a50, a53, a57, a59, a62, a65, a67, a68, a69, a70, a76, a77, a78, a83, a87, a88, a89, a90, a92, a102, a107, a110, a111, a112, a113, a117, a118, a119, a121, a122, a123, a124, a125, a126, a127, a128, a130, a133, a134, a140, a143, a144, a146, a147, a149.',
#        'c71 :- a0, a1, a2, a3, a4, a5, a6, a7, a8, a12, a13, a14, a15, a16, a17, a18, a22, a23, a24, a25, a27, a30, a32, a33, a36, a38, a39, a44, a46, a49, a58, a61, a62, a63, a64, a65, a67, a68, a70, a71, a72, a76, a78, a79, a81, a84, a85, a86, a87, a88, a89, a96, a101, a105, a107, a109, a110, a111, a112, a113, a117, a118, a119, a121, a122, a126, a127, a129, a130, a131, a133, a134, a135, a136, a138, a139, a140, a143, a144, a145, a146, a147, a148, a149.',
#        'c72 :- a1, a2, a3, a4, a5, a8, a9, a11, a13, a14, a15, a16, a19, a20, a22, a23, a26, a27, a29, a31, a32, a34, a35, a36, a37, a38, a39, a41, a42, a43, a45, a48, a50, a51, a52, a55, a57, a58, a62, a70, a72, a73, a75, a78, a80, a83, a84, a85, a86, a89, a93, a97, a101, a104, a107, a108, a109, a112, a113, a115, a116, a123, a129, a131, a133, a137, a139, a141, a143, a146, a148.',
#        'c73 :- a0, a2, a3, a4, a6, a7, a9, a11, a17, a19, a20, a23, a27, a34, a35, a38, a40, a41, a42, a43, a44, a47, a49, a50, a54, a55, a56, a59, a60, a62, a63, a64, a67, a70, a71, a73, a77, a82, a83, a85, a88, a90, a91, a94, a96, a97, a99, a102, a103, a104, a110, a112, a113, a115, a116, a117, a118, a119, a120, a121, a124, a126, a129, a130, a131, a132, a133, a134, a137, a138, a140, a141, a142, a143, a145.',
#        'c74 :- a1, a3, a7, a8, a11, a13, a14, a20, a22, a24, a26, a28, a30, a33, a35, a37, a38, a39, a41, a42, a43, a46, a48, a49, a52, a53, a54, a61, a63, a64, a65, a68, a71, a72, a73, a74, a75, a76, a77, a79, a81, a82, a89, a91, a93, a95, a100, a103, a104, a105, a107, a108, a109, a111, a112, a113, a114, a116, a117, a118, a119, a120, a121, a123, a125, a128, a129, a136, a139, a145, a146, a147, a148.',
#        'class_0 :- c1.', 'class_0 :- c2.', 'class_1 :- c3.',
#        'class_2 :- c6.', 'class_3 :- c11.', 'class_4 :- c13.',
#        'class_5 :- c15.', 'class_5 :- c17.', 'class_6 :- c20.',
#        'class_7 :- c22.', 'class_8 :- c24.', 'class_8 :- c25.',
#        'class_9 :- c28.', 'class_10 :- c31.', 'class_10 :- c32.',
#        'class_11 :- c35.', 'class_12 :- c36.', 'class_13 :- c39.',
#        'class_13 :- c40.', 'class_13 :- c41.', 'class_14 :- c43.',
#        'class_14 :- c44.', 'class_15 :- c46.', 'class_15 :- c47.',
#        'class_16 :- c48.', 'class_16 :- c50.', 'class_17 :- c51.',
#        'class_17 :- c52.', 'class_17 :- c53.', 'class_18 :- c54.',
#        'class_18 :- c56.', 'class_19 :- c58.', 'class_19 :- c59.',
#        'class_20 :- c61.', 'class_21 :- c64.', 'class_22 :- c67.',
#        'class_22 :- c68.', 'class_23 :- c69.', 'class_23 :- c71.',
#        'class_24 :- c72.'], dtype='<U478')
